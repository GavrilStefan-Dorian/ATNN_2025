# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import torch
from torch import nn, Tensor
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from torchvision.transforms import v2
from torch.backends import cudnn
from torch import GradScaler
from torch import optim
from tqdm import tqdm
import numpy as np
import pickle
import time

from torchvision.datasets import CIFAR10, CIFAR100, MNIST, OxfordIIITPet
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau
import timm
import wandb
wandb.login(key=os.getenv('WANDB_API_KEY'))
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter


print("Muon" in dir(torch.optim))
print(torch.__version__)
device = torch.accelerator.current_accelerator() if torch.accelerator.is_available() else torch.device("cpu")
enable_half = device.type != "cpu"
# scaler = torch.amp.GradScaler('cuda', enabled=enable_half)

print("Grad scaler is enabled:", enable_half)
print("Device:", device)

batch_size_map = {
    "resnet18": 128,
    "resnet50": 64,
    "resnest14d": 32,
    "resnest26d": 16,
    "mlp": 256
}   


class BatchSizeScheduler:
    def __init__(self, initial_batch_size, max_batch_size, step_size=30):
        self.initial_batch_size = initial_batch_size
        self.current_batch_size = initial_batch_size
        self.max_batch_size = max_batch_size
        self.step_size = step_size
        self.epoch = 0
    
    def step(self):
        self.epoch += 1
        if self.epoch % self.step_size == 0 and self.current_batch_size < self.max_batch_size:
            old_bs = self.current_batch_size
            self.current_batch_size = min(int(self.current_batch_size * 1.5), self.max_batch_size)
            if self.current_batch_size != old_bs:
                print(f"Batch size increased: {old_bs} → {self.current_batch_size}")
                return True
        return False
    
    def get_batch_size(self):
        return self.current_batch_size


def get_transforms(dataset, image_size, is_train=True, use_heavy_aug=False):
    if dataset == "MNIST":
        return v2.Compose([
            v2.ToImage(),
            v2.Resize(image_size),
            v2.ToDtype(torch.float32, scale=True),
        ])
    
    if dataset in ["CIFAR10", "CIFAR100"]:
        mean = (0.5071, 0.4867, 0.4408)
        std = (0.2675, 0.2565, 0.2761)
    else:  # OxfordIIITPet
        mean = (0.485, 0.456, 0.406)
        std = (0.229, 0.224, 0.225)
    
    if is_train:
        if image_size == 32:
            transforms_list = [
                v2.ToImage(),
                v2.RandomCrop(32, padding=4),
                v2.RandomHorizontalFlip(),
            ]
            if use_heavy_aug:
                transforms_list.append(v2.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3)))
            transforms_list.extend([
                v2.ToDtype(torch.float32, scale=True),
                v2.Normalize(mean, std)
            ])
            return v2.Compose(transforms_list)
        else:
            return v2.Compose([
                v2.ToImage(),
                v2.Resize(256),
                v2.RandomCrop(image_size),
                v2.RandomHorizontalFlip(),
                v2.ToDtype(torch.float32, scale=True),
                v2.Normalize(mean, std)
            ])
    else:
        return v2.Compose([
            v2.ToImage(),
            v2.Resize(image_size),
            v2.CenterCrop(image_size),
            v2.ToDtype(torch.float32, scale=True),
            v2.Normalize(mean, std)
        ])


# DATA_ROOT = "/kaggle/working/data"
# os.makedirs(DATA_ROOT, exist_ok=True)

def get_data_loaders(dataset_name, image_size, batch_size, num_workers=2, pin_memory=True, use_heavy_aug=False):
    train_transforms = get_transforms(dataset_name, image_size, is_train=True, use_heavy_aug=use_heavy_aug)
    test_transform = get_transforms(dataset_name, image_size, is_train=False)

    if dataset_name == "CIFAR100":
        train_dataset= CIFAR100(root='./data', train=True, download=True, transform=train_transforms)
        test_dataset = CIFAR100(root='./data', train=False, download=True, transform=test_transform)
    elif dataset_name == "CIFAR10":
        train_dataset= CIFAR10(root='./data', train=True, download=True, transform=train_transforms)
        test_dataset = CIFAR10(root='./data', train=False, download=True, transform=test_transform)
    elif dataset_name == "MNIST":
        train_dataset= MNIST(root='./data', train=True, download=True, transform=train_transforms)
        test_dataset = MNIST(root='./data', train=False, download=True, transform=test_transform)
    elif dataset_name == "OxfordIIITPet":
        train_dataset= OxfordIIITPet(root='./data', download=True, transform=train_transforms)
        test_dataset = OxfordIIITPet(root='./data', split='test', download=True, transform=test_transform)
    else:
        raise ValueError(f"Unsupported dataset: {dataset_name}")
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
    return train_loader, test_loader



def get_num_classes(dataset_name):
    if dataset_name in ["CIFAR100"]:
        return 100
    elif dataset_name in ["CIFAR10"]:
        return 10
    elif dataset_name in ["MNIST"]:
        return 10
    elif dataset_name in ["OxfordIIITPet"]:
        return 37
    else:
        raise ValueError(f"Unsupported dataset: {dataset_name}")


ALLOWED_MODELS = ["resnet18", "resnet50", "resnest14d", "resnest26d", "mlp"]

def create_model(model_name, dataset_name, pretrained=False, image_size=32):
    if model_name not in ALLOWED_MODELS:
        raise ValueError(f"Unsupported model: {model_name}")
    
    num_classes=get_num_classes(dataset_name)

    if model_name == "mlp":
        in_channels = 1 if dataset_name == "MNIST" else 3
        return nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_channels * image_size * image_size, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
    else:
        model = timm.create_model(model_name, pretrained=pretrained, num_classes=num_classes)
        if not pretrained and image_size == 32:
            if model_name.startswith("resnet") or model_name.startswith("resnest"):
                model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
                model.maxpool = nn.Identity()
    return model


class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, adaptive=False, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"
        self.rho = rho
        self.adaptive = adaptive

        defaults = dict(rho=rho, adaptive=adaptive, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()

        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None:
                    continue
                e = (torch.pow(p, 2) if group["adaptive"] else 1.0) * p.grad * scale
                p.add_(e)
                self.state[p]["e"] = e

        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None:
                    continue
                p.sub_(self.state[p]["e"])

        self.base_optimizer.step()

        if zero_grad:
            self.zero_grad()

    def zero_grad(self):
        self.base_optimizer.zero_grad()

    def step(self):
        raise RuntimeError("Use first_step() and second_step() with SAM.")
    
    def _grad_norm(self):
        norm = torch.norm(
            torch.stack([
                ((torch.pow(p, 2) if self.adaptive else 1.0) * p.grad).norm(p=2)
                for group in self.param_groups for p in group["params"]
                if p.grad is not None
            ]),
            p=2
        )
        return norm


def create_optimizer(optimizer_name, model_parameters, lr, weight_decay):
    if optimizer_name == "SGD":
        return optim.SGD(model_parameters, lr=lr, momentum=0.9, weight_decay=weight_decay)
    elif optimizer_name == "AdamW":
        return optim.AdamW(model_parameters, lr=lr, weight_decay=weight_decay)
    elif optimizer_name == "Adam":
        return optim.Adam(model_parameters, lr=lr, weight_decay=weight_decay)
    elif optimizer_name == "SAM":
        return SAM(model_parameters, base_optimizer=optim.SGD, lr=lr, momentum=0.9, weight_decay=weight_decay)
    elif optimizer_name == "Muon":
        return torch.optim.Muon(model_parameters, lr=lr, weight_decay=weight_decay)        
    else:
        raise ValueError(f"Unsupported optimizer: {optimizer_name}")


def create_scheduler(scheduler_name, optimizer, step_size=30):
    base_optimizer = optimizer.base_optimizer if isinstance(optimizer, SAM) else optimizer

    if scheduler_name == "StepLR":
        return StepLR(base_optimizer, step_size=step_size, gamma=0.1)
    elif scheduler_name == "ReduceLROnPlateau":
        return ReduceLROnPlateau(base_optimizer, patience=5)
    else:
        raise ValueError(f"Unsupported scheduler: {scheduler_name}")



def train_epoch(model, train_loader, criterion, optimizer, scaler, device, use_amp, 
                mixup_cutmix_transform=None):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        if mixup_cutmix_transform is not None:
            inputs, targets = mixup_cutmix_transform(inputs, targets)

        with torch.amp.autocast(device_type=device.type, enabled=use_amp):
            outputs = model(inputs)
            loss = criterion(outputs, targets)

        if isinstance(optimizer, SAM):
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer.base_optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.first_step(zero_grad=True)

            with torch.amp.autocast(device_type=device.type, enabled=use_amp):
                outputs = model(inputs)
                loss = criterion(outputs, targets)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer.base_optimizer)
            scaler.step(optimizer.base_optimizer)
            scaler.update()
            optimizer.zero_grad()
        else: 
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update() 
            optimizer.zero_grad()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        if targets.dim() > 1:  # Mixed labels (one-hot/ soft labels)
            correct += predicted.eq(targets.argmax(1)).sum().item()
        else:  # Regular 
            correct += predicted.eq(targets).sum().item()

    return train_loss / len(train_loader), 100.0 * correct/total


def test(model, test_loader, criterion, device, use_amp):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            with torch.amp.autocast(device_type=device.type, enabled=use_amp):
                outputs = model(inputs)
                loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    return test_loss / len(test_loader), 100.0 * correct/total


def train_model(config):
    label_smoothing = config.get("label_smoothing", 0.0)
    criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
    scaler = torch.amp.GradScaler(device.type, enabled=config["use_amp"])
    writer = SummaryWriter(log_dir=f'./logs/{config["dataset"]}/{config["optimizer"]}_{config["model"]}_bs{batch_size_map[config["model"]]}_lr{config["lr"]}_sched{config["scheduler"]}')

    image_size = 224 if config["pretrained"] else 32
    initial_batch_size = batch_size_map[config["model"]]
    
    use_bs_scheduler = config.get("use_batch_size_scheduler", False)
    if use_bs_scheduler:
        bs_scheduler = BatchSizeScheduler(
            initial_batch_size=initial_batch_size // 2, 
            max_batch_size=initial_batch_size,
            step_size=30
        )
        batch_size = bs_scheduler.get_batch_size()
        print(f"Batch size scheduler enabled: {batch_size} → {initial_batch_size}")
    else:
        batch_size = initial_batch_size

    use_heavy_aug = config.get("use_heavy_aug", False)
    train_loader, test_loader = get_data_loaders(config["dataset"], image_size, batch_size, config["num_workers"], config["pin_memory"], use_heavy_aug=use_heavy_aug) 
    model = create_model(config["model"], config["dataset"], config["pretrained"], image_size)
    model.to(device)

    optimizer = create_optimizer(config["optimizer"], model.parameters(), config["lr"], config["weight_decay"])
    
    step_size = config.get("step_size", 30)
    scheduler = create_scheduler(config["scheduler"], optimizer, step_size=step_size)

    epochs = config["epochs"]
    
    best_acc = 0.0
    best_acc_epoch = None
    counter = 0
    patience = config.get("patience", 10)

    mixup_cutmix_transform = None
    use_mixup = config.get("use_mixup", False)
    use_cutmix = config.get("use_cutmix", False)
    
    if use_mixup or use_cutmix:
        num_classes = get_num_classes(config["dataset"])
        transforms_list = []
        
        if use_mixup:
            mixup_alpha = config.get("mixup_alpha", 0.2)
            transforms_list.append(v2.MixUp(alpha=mixup_alpha, num_classes=num_classes))
        
        if use_cutmix:
            cutmix_alpha = config.get("cutmix_alpha", 0.2)
            transforms_list.append(v2.CutMix(alpha=cutmix_alpha, num_classes=num_classes))
        
        if len(transforms_list) > 1:
            mixup_cutmix_transform = v2.RandomChoice(transforms_list)
        else:
            mixup_cutmix_transform = transforms_list[0]

    start_time = time.time()
    print("Start training")
    
    for epoch in range(epochs):
        epoch_start = time.time()

        if use_bs_scheduler and bs_scheduler.step():
            batch_size = bs_scheduler.get_batch_size()
            train_loader, test_loader = get_data_loaders(
                config["dataset"], 
                image_size, 
                batch_size,
                config.get("num_workers", 2),
                config.get("pin_memory", True),
                use_heavy_aug=use_heavy_aug
            )

        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, scaler, device, config["use_amp"],
                                           mixup_cutmix_transform=mixup_cutmix_transform)
        test_loss, test_acc = test(model, test_loader, criterion, device, config["use_amp"])

        if isinstance(scheduler, StepLR):
            scheduler.step()
        elif isinstance(scheduler, ReduceLROnPlateau):
            scheduler.step(test_loss)
        
        if isinstance(optimizer, SAM):
            current_lr = optimizer.base_optimizer.param_groups[0]['lr']
        else:
            current_lr = optimizer.param_groups[0]['lr']
        
        epoch_time = time.time() - epoch_start

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%, LR: {current_lr:.6f}, Time: {epoch_time:.2f}s")
        
        if config["use_wandb"]:
            wandb.log({
                "epoch": epoch + 1,
                "train_loss": train_loss,
                "train_acc": train_acc,
                "val_loss": test_loss,
                "val_acc": test_acc,
                "lr": current_lr,
                "epoch_time": epoch_time,
                "batch_size": batch_size if use_bs_scheduler else initial_batch_size
            })

        writer.add_scalar('Loss/Train', train_loss, epoch)
        writer.add_scalar('Loss/Test', test_loss, epoch)
        writer.add_scalar('Accuracy/Train', train_acc, epoch)
        writer.add_scalar('Accuracy/Test', test_acc, epoch)
        writer.add_scalar('Learning Rate', current_lr, epoch)
        if use_bs_scheduler:
            writer.add_scalar('Batch_Size', batch_size, epoch)
        
        if test_acc > best_acc:
            best_acc = test_acc
            os.makedirs('./checkpoints', exist_ok=True)

            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_acc': best_acc,    
                'config': config    
            }, f'./checkpoints/{config["optimizer"]}_{config["model"]}_bs{batch_size_map[config["model"]]}_lr{config["lr"]}_sched{config["scheduler"]}.pth')
            print(f"Best model saved with accuracy: {best_acc:.2f}%")

        # Early stop mechanism
        if best_acc_epoch is None:
            best_acc_epoch = test_acc
        elif test_acc < best_acc_epoch:
            counter += 1
            if counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                break
        else:
            best_acc_epoch = test_acc
            counter = 0

    total_time = time.time() - start_time
    print(f"Training completed in {total_time/60:.2f} minutes")
    print(f"Best Test Accuracy: {best_acc:.2f}%")
    
    writer.close()

    if config["use_wandb"]:
        wandb.log({
            "best_acc": best_acc,
            "total_time": total_time
        })

    return {
        'best_acc': best_acc,
        'total_time': total_time,
        'final_train_acc': train_acc,
        'final_test_acc': test_acc
    }


def create_sweep_config(pretrained=False):
    if pretrained:
        return {
            "method": "grid",
            "metric": {"name": "val_acc", "goal": "maximize"},
            "parameters": {
                "dataset": {"value": "CIFAR100"},
                "model": {"values": ["resnet18", "resnet50"]},
                "pretrained": {"value": True}, 
                "lr": {"values": [3e-4, 1e-4]},
                "optimizer": {"value": "AdamW"},  
                "scheduler": {"value": "StepLR"},  
                "epochs": {"value": 100},
                "weight_decay": {"value": 1e-2},
                "num_workers": {"value": 2},  
                "pin_memory": {"value": True},
                "use_amp": {"value": True},  
                "use_wandb": {"value": True},
                "use_batch_size_scheduler": {"value": False}
            }
        }
    else:
        return {
            "method": "grid",
            "metric": {"name": "val_acc", "goal": "maximize"},
            "parameters": {
                "dataset": {"value": "CIFAR100"},
                "model": {"values": ["resnet50"]},
                "pretrained": {"value": False}, 
                "lr": {"values": [0.1]},  
                "optimizer": {"values": ["SGD"]},
                "scheduler": {"value": "StepLR"},
                "step_size": {"value": 50},
                "epochs": {"value": 200},
                "weight_decay": {"value": 5e-4},
                "num_workers": {"value": 2}, 
                "pin_memory": {"value": True},
                "use_amp": {"value": True}, 
                "use_wandb": {"value": True},
                "use_batch_size_scheduler": {"value": False},
                "use_heavy_aug": {"value": True},
                "use_mixup": {"value": True},
                "mixup_alpha": {"value": 0.2},
                "use_cutmix": {"value": True},
                "cutmix_alpha": {"value": 0.2},
                "label_smoothing": {"value": 0.1},
                "patience": {"value": 20}
            }
        }


def sweep_train():
    run = wandb.init(project="training_pipeline")
    cfg = dict(wandb.config)
    results = train_model(cfg)
    run.finish()
    

sweep_config = create_sweep_config(pretrained=False)
sweep_id = wandb.sweep(sweep_config, project="training_pipeline")
wandb.agent(sweep_id, function=sweep_train)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /teamspace/studios/this_studio/.netrc
# True
# 2.9.1+cu126
# Grad scaler is enabled: True
# Device: cuda
# Create sweep with ID: wkum883d
# Sweep URL: https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/wkum883d
# wandb: Agent Starting Run: c5qttuhi with config:
# wandb: 	cutmix_alpha: 0.2
# wandb: 	dataset: CIFAR100
# wandb: 	epochs: 200
# wandb: 	label_smoothing: 0.1
# wandb: 	lr: 0.1
# wandb: 	mixup_alpha: 0.2
# wandb: 	model: resnet50
# wandb: 	num_workers: 2
# wandb: 	optimizer: SGD
# wandb: 	patience: 20
# wandb: 	pin_memory: True
# wandb: 	pretrained: False
# wandb: 	scheduler: StepLR
# wandb: 	step_size: 50
# wandb: 	use_amp: True
# wandb: 	use_batch_size_scheduler: False
# wandb: 	use_cutmix: True
# wandb: 	use_heavy_aug: True
# wandb: 	use_mixup: True
# wandb: 	use_wandb: True
# wandb: 	weight_decay: 0.0005
# Ignoring project 'training_pipeline' when running a sweep.
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>/teamspace/studios/this_studio/wandb/run-20251121_193504-c5qttuhi</code>
# Syncing run <strong><a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/c5qttuhi' target="_blank">fancy-sweep-1</a></strong> to <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/wkum883d' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/wkum883d</a>
#  View project at <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline</a>
#  View sweep at <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/wkum883d' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/wkum883d</a>
#  View run at <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/c5qttuhi' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/c5qttuhi</a>
# Start training
# Epoch 1/200, Train Loss: 4.3629, Train Acc: 4.45%, Test Loss: 3.9985, Test Acc: 10.63%, LR: 0.100000, Time: 64.14s
# Best model saved with accuracy: 10.63%
# Epoch 2/200, Train Loss: 4.0911, Train Acc: 7.20%, Test Loss: 3.7444, Test Acc: 14.93%, LR: 0.100000, Time: 63.51s
# Best model saved with accuracy: 14.93%
# Epoch 3/200, Train Loss: 3.8897, Train Acc: 10.44%, Test Loss: 3.4718, Test Acc: 21.08%, LR: 0.100000, Time: 63.58s
# Best model saved with accuracy: 21.08%
# Epoch 4/200, Train Loss: 3.6674, Train Acc: 13.96%, Test Loss: 3.2511, Test Acc: 26.06%, LR: 0.100000, Time: 63.67s
# Best model saved with accuracy: 26.06%
# Epoch 5/200, Train Loss: 3.5237, Train Acc: 17.16%, Test Loss: 3.2395, Test Acc: 26.91%, LR: 0.100000, Time: 63.55s
# Best model saved with accuracy: 26.91%
# Epoch 6/200, Train Loss: 3.4358, Train Acc: 18.65%, Test Loss: 3.0435, Test Acc: 32.83%, LR: 0.100000, Time: 63.57s
# Best model saved with accuracy: 32.83%
# Epoch 7/200, Train Loss: 3.3761, Train Acc: 19.06%, Test Loss: 3.1841, Test Acc: 28.87%, LR: 0.100000, Time: 63.55s
# Epoch 8/200, Train Loss: 3.3118, Train Acc: 20.62%, Test Loss: 2.9427, Test Acc: 34.51%, LR: 0.100000, Time: 63.53s
# Best model saved with accuracy: 34.51%
# Epoch 9/200, Train Loss: 3.2999, Train Acc: 20.53%, Test Loss: 2.8816, Test Acc: 36.36%, LR: 0.100000, Time: 63.59s
# Best model saved with accuracy: 36.36%
# Epoch 10/200, Train Loss: 3.2487, Train Acc: 21.89%, Test Loss: 3.0625, Test Acc: 32.75%, LR: 0.100000, Time: 63.51s
# Epoch 11/200, Train Loss: 3.2411, Train Acc: 22.29%, Test Loss: 2.8825, Test Acc: 36.06%, LR: 0.100000, Time: 63.21s
# Epoch 12/200, Train Loss: 3.2248, Train Acc: 22.25%, Test Loss: 2.8114, Test Acc: 37.67%, LR: 0.100000, Time: 63.19s
# Best model saved with accuracy: 37.67%
# Epoch 13/200, Train Loss: 3.1865, Train Acc: 22.74%, Test Loss: 2.7998, Test Acc: 37.04%, LR: 0.100000, Time: 63.21s
# Epoch 14/200, Train Loss: 3.1783, Train Acc: 23.25%, Test Loss: 2.7437, Test Acc: 38.77%, LR: 0.100000, Time: 63.28s
# Best model saved with accuracy: 38.77%
# Epoch 15/200, Train Loss: 3.1659, Train Acc: 24.18%, Test Loss: 2.6456, Test Acc: 41.96%, LR: 0.100000, Time: 63.20s
# Best model saved with accuracy: 41.96%
# Epoch 16/200, Train Loss: 3.1710, Train Acc: 22.74%, Test Loss: 2.7870, Test Acc: 38.20%, LR: 0.100000, Time: 63.20s
# Epoch 17/200, Train Loss: 3.1299, Train Acc: 25.37%, Test Loss: 2.9177, Test Acc: 36.38%, LR: 0.100000, Time: 63.15s
# Epoch 18/200, Train Loss: 3.1400, Train Acc: 23.94%, Test Loss: 2.6986, Test Acc: 40.47%, LR: 0.100000, Time: 63.11s
# Epoch 19/200, Train Loss: 3.1110, Train Acc: 25.25%, Test Loss: 2.6238, Test Acc: 42.57%, LR: 0.100000, Time: 63.14s
# Best model saved with accuracy: 42.57%
# Epoch 20/200, Train Loss: 3.0951, Train Acc: 25.35%, Test Loss: 2.7232, Test Acc: 39.46%, LR: 0.100000, Time: 63.16s
# Epoch 21/200, Train Loss: 3.0917, Train Acc: 25.17%, Test Loss: 2.6788, Test Acc: 41.20%, LR: 0.100000, Time: 63.08s
# Epoch 22/200, Train Loss: 3.0556, Train Acc: 25.56%, Test Loss: 2.6549, Test Acc: 42.43%, LR: 0.100000, Time: 63.08s
# Epoch 23/200, Train Loss: 3.0580, Train Acc: 25.83%, Test Loss: 2.8013, Test Acc: 38.06%, LR: 0.100000, Time: 63.09s
# Epoch 24/200, Train Loss: 3.0803, Train Acc: 25.41%, Test Loss: 2.5138, Test Acc: 45.48%, LR: 0.100000, Time: 63.09s
# Best model saved with accuracy: 45.48%
# Epoch 25/200, Train Loss: 3.0771, Train Acc: 25.18%, Test Loss: 3.1372, Test Acc: 32.66%, LR: 0.100000, Time: 63.05s
# Epoch 26/200, Train Loss: 3.0740, Train Acc: 25.59%, Test Loss: 2.7212, Test Acc: 42.06%, LR: 0.100000, Time: 63.02s
# Epoch 27/200, Train Loss: 3.0308, Train Acc: 25.42%, Test Loss: 2.6936, Test Acc: 41.26%, LR: 0.100000, Time: 63.11s
# Epoch 28/200, Train Loss: 3.0886, Train Acc: 25.25%, Test Loss: 2.6184, Test Acc: 43.57%, LR: 0.100000, Time: 63.12s
# Epoch 29/200, Train Loss: 3.0540, Train Acc: 25.65%, Test Loss: 2.5271, Test Acc: 46.35%, LR: 0.100000, Time: 63.09s
# Best model saved with accuracy: 46.35%
# Epoch 30/200, Train Loss: 3.0486, Train Acc: 25.95%, Test Loss: 2.5841, Test Acc: 44.44%, LR: 0.100000, Time: 63.18s
# Epoch 31/200, Train Loss: 3.0415, Train Acc: 26.55%, Test Loss: 2.9092, Test Acc: 39.28%, LR: 0.100000, Time: 63.09s
# Epoch 32/200, Train Loss: 3.0755, Train Acc: 25.92%, Test Loss: 2.7359, Test Acc: 40.63%, LR: 0.100000, Time: 63.10s
# Epoch 33/200, Train Loss: 3.0250, Train Acc: 26.47%, Test Loss: 2.8031, Test Acc: 40.23%, LR: 0.100000, Time: 63.31s
# Epoch 34/200, Train Loss: 3.0385, Train Acc: 27.74%, Test Loss: 2.4924, Test Acc: 46.76%, LR: 0.100000, Time: 63.16s
# Best model saved with accuracy: 46.76%
# Epoch 35/200, Train Loss: 3.0182, Train Acc: 27.02%, Test Loss: 2.5904, Test Acc: 44.42%, LR: 0.100000, Time: 63.19s
# Epoch 36/200, Train Loss: 3.0365, Train Acc: 26.69%, Test Loss: 2.7253, Test Acc: 41.00%, LR: 0.100000, Time: 63.47s
# Epoch 37/200, Train Loss: 3.0119, Train Acc: 27.20%, Test Loss: 2.6089, Test Acc: 44.47%, LR: 0.100000, Time: 63.44s
# Epoch 38/200, Train Loss: 3.0519, Train Acc: 26.27%, Test Loss: 2.5902, Test Acc: 44.42%, LR: 0.100000, Time: 63.44s
# Epoch 39/200, Train Loss: 3.0190, Train Acc: 27.22%, Test Loss: 2.8872, Test Acc: 37.90%, LR: 0.100000, Time: 63.03s
# Epoch 40/200, Train Loss: 3.0065, Train Acc: 25.81%, Test Loss: 2.5912, Test Acc: 44.34%, LR: 0.100000, Time: 63.06s
# Epoch 41/200, Train Loss: 3.0286, Train Acc: 26.46%, Test Loss: 2.7485, Test Acc: 42.03%, LR: 0.100000, Time: 63.07s
# Epoch 42/200, Train Loss: 3.0211, Train Acc: 26.52%, Test Loss: 2.5769, Test Acc: 45.41%, LR: 0.100000, Time: 63.04s
# Epoch 43/200, Train Loss: 3.0219, Train Acc: 27.75%, Test Loss: 2.6133, Test Acc: 44.28%, LR: 0.100000, Time: 63.07s
# Epoch 44/200, Train Loss: 3.0141, Train Acc: 25.57%, Test Loss: 2.7063, Test Acc: 42.75%, LR: 0.100000, Time: 63.05s
# Epoch 45/200, Train Loss: 3.0026, Train Acc: 26.82%, Test Loss: 2.5370, Test Acc: 45.78%, LR: 0.100000, Time: 63.02s
# Epoch 46/200, Train Loss: 2.9952, Train Acc: 27.96%, Test Loss: 2.7750, Test Acc: 40.34%, LR: 0.100000, Time: 62.98s
# Epoch 47/200, Train Loss: 2.9737, Train Acc: 27.08%, Test Loss: 2.7457, Test Acc: 40.99%, LR: 0.100000, Time: 63.04s
# Epoch 48/200, Train Loss: 3.0114, Train Acc: 26.33%, Test Loss: 2.5223, Test Acc: 45.11%, LR: 0.100000, Time: 63.05s
# Epoch 49/200, Train Loss: 2.9531, Train Acc: 27.16%, Test Loss: 2.4893, Test Acc: 46.82%, LR: 0.100000, Time: 63.11s
# Best model saved with accuracy: 46.82%
# Epoch 50/200, Train Loss: 2.9739, Train Acc: 27.42%, Test Loss: 2.6376, Test Acc: 44.72%, LR: 0.010000, Time: 63.10s
# Epoch 51/200, Train Loss: 2.6053, Train Acc: 36.69%, Test Loss: 1.8419, Test Acc: 65.71%, LR: 0.010000, Time: 63.17s
# Best model saved with accuracy: 65.71%
# Epoch 52/200, Train Loss: 2.5043, Train Acc: 38.23%, Test Loss: 1.7848, Test Acc: 67.39%, LR: 0.010000, Time: 63.02s
# Best model saved with accuracy: 67.39%
# Epoch 53/200, Train Loss: 2.4731, Train Acc: 38.95%, Test Loss: 1.7546, Test Acc: 68.25%, LR: 0.010000, Time: 63.10s
# Best model saved with accuracy: 68.25%
# Epoch 54/200, Train Loss: 2.4279, Train Acc: 40.49%, Test Loss: 1.7309, Test Acc: 69.15%, LR: 0.010000, Time: 63.07s
# Best model saved with accuracy: 69.15%
# Epoch 55/200, Train Loss: 2.3616, Train Acc: 41.38%, Test Loss: 1.7488, Test Acc: 68.67%, LR: 0.010000, Time: 63.08s
# Epoch 56/200, Train Loss: 2.3854, Train Acc: 41.05%, Test Loss: 1.7043, Test Acc: 69.63%, LR: 0.010000, Time: 63.08s
# Best model saved with accuracy: 69.63%
# Epoch 57/200, Train Loss: 2.3502, Train Acc: 40.82%, Test Loss: 1.7097, Test Acc: 69.98%, LR: 0.010000, Time: 63.06s
# Best model saved with accuracy: 69.98%
# Epoch 58/200, Train Loss: 2.3342, Train Acc: 40.60%, Test Loss: 1.7128, Test Acc: 69.54%, LR: 0.010000, Time: 63.15s
# Epoch 59/200, Train Loss: 2.3322, Train Acc: 39.95%, Test Loss: 1.7109, Test Acc: 70.17%, LR: 0.010000, Time: 63.07s
# Best model saved with accuracy: 70.17%
# Epoch 60/200, Train Loss: 2.3289, Train Acc: 42.61%, Test Loss: 1.6930, Test Acc: 70.54%, LR: 0.010000, Time: 63.06s
# Best model saved with accuracy: 70.54%
# Epoch 61/200, Train Loss: 2.3147, Train Acc: 42.81%, Test Loss: 1.7412, Test Acc: 68.64%, LR: 0.010000, Time: 63.15s
# Epoch 62/200, Train Loss: 2.3352, Train Acc: 40.40%, Test Loss: 1.7261, Test Acc: 69.53%, LR: 0.010000, Time: 63.14s
# Epoch 63/200, Train Loss: 2.3635, Train Acc: 41.98%, Test Loss: 1.6896, Test Acc: 70.68%, LR: 0.010000, Time: 63.14s
# Best model saved with accuracy: 70.68%
# Epoch 64/200, Train Loss: 2.2631, Train Acc: 42.95%, Test Loss: 1.7114, Test Acc: 70.45%, LR: 0.010000, Time: 63.14s
# Epoch 65/200, Train Loss: 2.2634, Train Acc: 43.79%, Test Loss: 1.7385, Test Acc: 68.90%, LR: 0.010000, Time: 63.21s
# Epoch 66/200, Train Loss: 2.3339, Train Acc: 41.60%, Test Loss: 1.7300, Test Acc: 69.38%, LR: 0.010000, Time: 63.13s
# Epoch 67/200, Train Loss: 2.2519, Train Acc: 43.71%, Test Loss: 1.7333, Test Acc: 68.82%, LR: 0.010000, Time: 63.11s
# Epoch 68/200, Train Loss: 2.2971, Train Acc: 43.26%, Test Loss: 1.7081, Test Acc: 69.89%, LR: 0.010000, Time: 63.14s
# Epoch 69/200, Train Loss: 2.2445, Train Acc: 43.81%, Test Loss: 1.7105, Test Acc: 69.52%, LR: 0.010000, Time: 63.00s
# Epoch 70/200, Train Loss: 2.2959, Train Acc: 43.80%, Test Loss: 1.7145, Test Acc: 70.32%, LR: 0.010000, Time: 63.01s
# Epoch 71/200, Train Loss: 2.2925, Train Acc: 42.78%, Test Loss: 1.6890, Test Acc: 70.43%, LR: 0.010000, Time: 62.94s
# Epoch 72/200, Train Loss: 2.2253, Train Acc: 43.97%, Test Loss: 1.7790, Test Acc: 68.28%, LR: 0.010000, Time: 62.96s
# Epoch 73/200, Train Loss: 2.2463, Train Acc: 44.01%, Test Loss: 1.6911, Test Acc: 70.19%, LR: 0.010000, Time: 63.01s
# Epoch 74/200, Train Loss: 2.1948, Train Acc: 44.90%, Test Loss: 1.7383, Test Acc: 68.61%, LR: 0.010000, Time: 63.08s
# Epoch 75/200, Train Loss: 2.2474, Train Acc: 42.84%, Test Loss: 1.6992, Test Acc: 70.50%, LR: 0.010000, Time: 63.04s
# Epoch 76/200, Train Loss: 2.2757, Train Acc: 43.33%, Test Loss: 1.6968, Test Acc: 70.13%, LR: 0.010000, Time: 62.99s
# Epoch 77/200, Train Loss: 2.2238, Train Acc: 44.85%, Test Loss: 1.6969, Test Acc: 70.59%, LR: 0.010000, Time: 63.03s
# Epoch 78/200, Train Loss: 2.1899, Train Acc: 45.28%, Test Loss: 1.7731, Test Acc: 68.04%, LR: 0.010000, Time: 63.06s
# Epoch 79/200, Train Loss: 2.2123, Train Acc: 42.66%, Test Loss: 1.7417, Test Acc: 69.90%, LR: 0.010000, Time: 62.98s
# Epoch 80/200, Train Loss: 2.1894, Train Acc: 45.90%, Test Loss: 1.6883, Test Acc: 70.68%, LR: 0.010000, Time: 63.05s
# Epoch 81/200, Train Loss: 2.2286, Train Acc: 44.45%, Test Loss: 1.6573, Test Acc: 71.78%, LR: 0.010000, Time: 63.05s
# Best model saved with accuracy: 71.78%
# Epoch 82/200, Train Loss: 2.2482, Train Acc: 45.38%, Test Loss: 1.6373, Test Acc: 72.20%, LR: 0.010000, Time: 63.11s
# Best model saved with accuracy: 72.20%
# Epoch 83/200, Train Loss: 2.1708, Train Acc: 44.04%, Test Loss: 1.6856, Test Acc: 70.84%, LR: 0.010000, Time: 63.00s
# Epoch 84/200, Train Loss: 2.1957, Train Acc: 43.35%, Test Loss: 1.7243, Test Acc: 70.23%, LR: 0.010000, Time: 62.98s
# Epoch 85/200, Train Loss: 2.1811, Train Acc: 45.44%, Test Loss: 1.6893, Test Acc: 70.54%, LR: 0.010000, Time: 63.15s
# Epoch 86/200, Train Loss: 2.1681, Train Acc: 45.15%, Test Loss: 1.6912, Test Acc: 70.75%, LR: 0.010000, Time: 63.06s
# Epoch 87/200, Train Loss: 2.1714, Train Acc: 43.66%, Test Loss: 1.6689, Test Acc: 71.61%, LR: 0.010000, Time: 63.06s
# Epoch 88/200, Train Loss: 2.1972, Train Acc: 46.25%, Test Loss: 1.6867, Test Acc: 70.78%, LR: 0.010000, Time: 63.06s
# Epoch 89/200, Train Loss: 2.1954, Train Acc: 44.78%, Test Loss: 1.6901, Test Acc: 71.45%, LR: 0.010000, Time: 63.01s
# Epoch 90/200, Train Loss: 2.1802, Train Acc: 44.26%, Test Loss: 1.6865, Test Acc: 70.51%, LR: 0.010000, Time: 63.05s
# Epoch 91/200, Train Loss: 2.1809, Train Acc: 45.58%, Test Loss: 1.6847, Test Acc: 71.17%, LR: 0.010000, Time: 63.04s
# Epoch 92/200, Train Loss: 2.2038, Train Acc: 44.72%, Test Loss: 1.6823, Test Acc: 70.86%, LR: 0.010000, Time: 63.05s
# Epoch 93/200, Train Loss: 2.1545, Train Acc: 43.27%, Test Loss: 1.7385, Test Acc: 70.17%, LR: 0.010000, Time: 63.07s
# Epoch 94/200, Train Loss: 2.1643, Train Acc: 45.10%, Test Loss: 1.7969, Test Acc: 68.51%, LR: 0.010000, Time: 63.05s
# Epoch 95/200, Train Loss: 2.1372, Train Acc: 45.98%, Test Loss: 1.6736, Test Acc: 71.67%, LR: 0.010000, Time: 63.23s
# Epoch 96/200, Train Loss: 2.1328, Train Acc: 47.71%, Test Loss: 1.6962, Test Acc: 70.81%, LR: 0.010000, Time: 63.41s
# Epoch 97/200, Train Loss: 2.1753, Train Acc: 43.98%, Test Loss: 1.6848, Test Acc: 71.42%, LR: 0.010000, Time: 63.25s
# Epoch 98/200, Train Loss: 2.1288, Train Acc: 47.20%, Test Loss: 1.6540, Test Acc: 73.00%, LR: 0.010000, Time: 63.41s
# Best model saved with accuracy: 73.00%
# Epoch 99/200, Train Loss: 2.1445, Train Acc: 44.88%, Test Loss: 1.7423, Test Acc: 69.56%, LR: 0.010000, Time: 63.26s
# Epoch 100/200, Train Loss: 2.1178, Train Acc: 45.25%, Test Loss: 1.6338, Test Acc: 72.72%, LR: 0.001000, Time: 63.24s
# Epoch 101/200, Train Loss: 1.9415, Train Acc: 49.34%, Test Loss: 1.4479, Test Acc: 78.47%, LR: 0.001000, Time: 63.21s
# Best model saved with accuracy: 78.47%
# Epoch 102/200, Train Loss: 1.9061, Train Acc: 53.06%, Test Loss: 1.4401, Test Acc: 78.97%, LR: 0.001000, Time: 63.62s
# Best model saved with accuracy: 78.97%
# Epoch 103/200, Train Loss: 1.8615, Train Acc: 52.34%, Test Loss: 1.4348, Test Acc: 79.11%, LR: 0.001000, Time: 63.68s
# Best model saved with accuracy: 79.11%
# Epoch 104/200, Train Loss: 1.8610, Train Acc: 54.01%, Test Loss: 1.4328, Test Acc: 79.25%, LR: 0.001000, Time: 63.64s
# Best model saved with accuracy: 79.25%
# Epoch 105/200, Train Loss: 1.8606, Train Acc: 53.05%, Test Loss: 1.4321, Test Acc: 79.16%, LR: 0.001000, Time: 63.58s
# Epoch 106/200, Train Loss: 1.8723, Train Acc: 53.19%, Test Loss: 1.4292, Test Acc: 79.29%, LR: 0.001000, Time: 63.02s
# Best model saved with accuracy: 79.29%
# Epoch 107/200, Train Loss: 1.8274, Train Acc: 53.81%, Test Loss: 1.4338, Test Acc: 79.37%, LR: 0.001000, Time: 62.99s
# Best model saved with accuracy: 79.37%
# Epoch 108/200, Train Loss: 1.8105, Train Acc: 53.92%, Test Loss: 1.4123, Test Acc: 79.83%, LR: 0.001000, Time: 63.02s
# Best model saved with accuracy: 79.83%
# Epoch 109/200, Train Loss: 1.8375, Train Acc: 53.12%, Test Loss: 1.4139, Test Acc: 79.57%, LR: 0.001000, Time: 63.05s
# Epoch 110/200, Train Loss: 1.8313, Train Acc: 54.76%, Test Loss: 1.4189, Test Acc: 79.56%, LR: 0.001000, Time: 63.07s
# Epoch 111/200, Train Loss: 1.8332, Train Acc: 52.74%, Test Loss: 1.4172, Test Acc: 79.62%, LR: 0.001000, Time: 63.18s
# Epoch 112/200, Train Loss: 1.7988, Train Acc: 55.68%, Test Loss: 1.4259, Test Acc: 79.35%, LR: 0.001000, Time: 63.18s
# Epoch 113/200, Train Loss: 1.7842, Train Acc: 52.83%, Test Loss: 1.4115, Test Acc: 79.93%, LR: 0.001000, Time: 63.08s
# Best model saved with accuracy: 79.93%
# Epoch 114/200, Train Loss: 1.8137, Train Acc: 54.34%, Test Loss: 1.4087, Test Acc: 79.93%, LR: 0.001000, Time: 63.05s
# Epoch 115/200, Train Loss: 1.7680, Train Acc: 53.55%, Test Loss: 1.4176, Test Acc: 79.62%, LR: 0.001000, Time: 63.10s
# Epoch 116/200, Train Loss: 1.6866, Train Acc: 55.45%, Test Loss: 1.4075, Test Acc: 80.24%, LR: 0.001000, Time: 63.12s
# Best model saved with accuracy: 80.24%
# Epoch 117/200, Train Loss: 1.7527, Train Acc: 55.60%, Test Loss: 1.4333, Test Acc: 79.70%, LR: 0.001000, Time: 63.15s
# Epoch 118/200, Train Loss: 1.8208, Train Acc: 53.89%, Test Loss: 1.4175, Test Acc: 79.77%, LR: 0.001000, Time: 63.22s
# Epoch 119/200, Train Loss: 1.7710, Train Acc: 54.01%, Test Loss: 1.4142, Test Acc: 79.91%, LR: 0.001000, Time: 63.17s
# Epoch 120/200, Train Loss: 1.7784, Train Acc: 54.14%, Test Loss: 1.4260, Test Acc: 79.83%, LR: 0.001000, Time: 63.15s
# Epoch 121/200, Train Loss: 1.7880, Train Acc: 52.85%, Test Loss: 1.4281, Test Acc: 79.68%, LR: 0.001000, Time: 63.11s
# Epoch 122/200, Train Loss: 1.7881, Train Acc: 54.69%, Test Loss: 1.4404, Test Acc: 79.30%, LR: 0.001000, Time: 63.11s
# Epoch 123/200, Train Loss: 1.7787, Train Acc: 53.09%, Test Loss: 1.4312, Test Acc: 79.81%, LR: 0.001000, Time: 63.26s
# Epoch 124/200, Train Loss: 1.7653, Train Acc: 57.26%, Test Loss: 1.4164, Test Acc: 79.78%, LR: 0.001000, Time: 63.43s
# Epoch 125/200, Train Loss: 1.6779, Train Acc: 57.71%, Test Loss: 1.4212, Test Acc: 79.78%, LR: 0.001000, Time: 63.42s
# Epoch 126/200, Train Loss: 1.7284, Train Acc: 54.34%, Test Loss: 1.4314, Test Acc: 79.68%, LR: 0.001000, Time: 63.44s
# Epoch 127/200, Train Loss: 1.7042, Train Acc: 57.79%, Test Loss: 1.4165, Test Acc: 79.77%, LR: 0.001000, Time: 63.48s
# Epoch 128/200, Train Loss: 1.7209, Train Acc: 54.78%, Test Loss: 1.4084, Test Acc: 80.25%, LR: 0.001000, Time: 63.42s
# Best model saved with accuracy: 80.25%
# Epoch 129/200, Train Loss: 1.7298, Train Acc: 54.94%, Test Loss: 1.4122, Test Acc: 80.07%, LR: 0.001000, Time: 63.30s
# Epoch 130/200, Train Loss: 1.7277, Train Acc: 56.57%, Test Loss: 1.4220, Test Acc: 79.57%, LR: 0.001000, Time: 63.36s
# Epoch 131/200, Train Loss: 1.7458, Train Acc: 57.40%, Test Loss: 1.4224, Test Acc: 79.92%, LR: 0.001000, Time: 63.33s
# Epoch 132/200, Train Loss: 1.7475, Train Acc: 56.99%, Test Loss: 1.4716, Test Acc: 79.07%, LR: 0.001000, Time: 63.34s
# Epoch 133/200, Train Loss: 1.7094, Train Acc: 56.47%, Test Loss: 1.4283, Test Acc: 79.91%, LR: 0.001000, Time: 63.23s
# Epoch 134/200, Train Loss: 1.6938, Train Acc: 55.48%, Test Loss: 1.4423, Test Acc: 79.65%, LR: 0.001000, Time: 63.36s
# Epoch 135/200, Train Loss: 1.7074, Train Acc: 55.00%, Test Loss: 1.4167, Test Acc: 80.03%, LR: 0.001000, Time: 63.30s
# Epoch 136/200, Train Loss: 1.7090, Train Acc: 57.22%, Test Loss: 1.4176, Test Acc: 79.84%, LR: 0.001000, Time: 63.28s
# Epoch 137/200, Train Loss: 1.7016, Train Acc: 58.17%, Test Loss: 1.4243, Test Acc: 80.06%, LR: 0.001000, Time: 63.29s
# Epoch 138/200, Train Loss: 1.7185, Train Acc: 57.13%, Test Loss: 1.4071, Test Acc: 80.31%, LR: 0.001000, Time: 63.32s
# Best model saved with accuracy: 80.31%
# Epoch 139/200, Train Loss: 1.6703, Train Acc: 56.58%, Test Loss: 1.4370, Test Acc: 79.63%, LR: 0.001000, Time: 63.20s
# Epoch 140/200, Train Loss: 1.7032, Train Acc: 55.44%, Test Loss: 1.4338, Test Acc: 79.89%, LR: 0.001000, Time: 63.03s
# Epoch 141/200, Train Loss: 1.7118, Train Acc: 56.90%, Test Loss: 1.4116, Test Acc: 80.22%, LR: 0.001000, Time: 63.00s
# Epoch 142/200, Train Loss: 1.6935, Train Acc: 55.66%, Test Loss: 1.4211, Test Acc: 80.14%, LR: 0.001000, Time: 62.98s
# Epoch 143/200, Train Loss: 1.6813, Train Acc: 55.96%, Test Loss: 1.4363, Test Acc: 79.71%, LR: 0.001000, Time: 63.06s
# Epoch 144/200, Train Loss: 1.6393, Train Acc: 54.94%, Test Loss: 1.4314, Test Acc: 79.91%, LR: 0.001000, Time: 63.31s
# Epoch 145/200, Train Loss: 1.7077, Train Acc: 59.40%, Test Loss: 1.4264, Test Acc: 79.73%, LR: 0.001000, Time: 63.26s
# Epoch 146/200, Train Loss: 1.6897, Train Acc: 57.58%, Test Loss: 1.4376, Test Acc: 79.65%, LR: 0.001000, Time: 62.97s
# Epoch 147/200, Train Loss: 1.6887, Train Acc: 55.43%, Test Loss: 1.4311, Test Acc: 79.73%, LR: 0.001000, Time: 62.94s
# Epoch 148/200, Train Loss: 1.6806, Train Acc: 57.64%, Test Loss: 1.4186, Test Acc: 80.07%, LR: 0.001000, Time: 63.00s
# Epoch 149/200, Train Loss: 1.6864, Train Acc: 59.34%, Test Loss: 1.4166, Test Acc: 80.29%, LR: 0.001000, Time: 62.99s
# Epoch 150/200, Train Loss: 1.6909, Train Acc: 59.09%, Test Loss: 1.4297, Test Acc: 79.84%, LR: 0.000100, Time: 62.98s
# Epoch 151/200, Train Loss: 1.6779, Train Acc: 58.49%, Test Loss: 1.4056, Test Acc: 80.53%, LR: 0.000100, Time: 63.13s
# Best model saved with accuracy: 80.53%
# Epoch 152/200, Train Loss: 1.6730, Train Acc: 58.66%, Test Loss: 1.4034, Test Acc: 80.89%, LR: 0.000100, Time: 63.04s
# Best model saved with accuracy: 80.89%
# Epoch 153/200, Train Loss: 1.6487, Train Acc: 61.48%, Test Loss: 1.4019, Test Acc: 80.64%, LR: 0.000100, Time: 62.95s
# Epoch 154/200, Train Loss: 1.6375, Train Acc: 58.84%, Test Loss: 1.4166, Test Acc: 80.58%, LR: 0.000100, Time: 63.07s
# Epoch 155/200, Train Loss: 1.6480, Train Acc: 54.86%, Test Loss: 1.4277, Test Acc: 80.46%, LR: 0.000100, Time: 63.01s
# Epoch 156/200, Train Loss: 1.6165, Train Acc: 57.61%, Test Loss: 1.4001, Test Acc: 80.64%, LR: 0.000100, Time: 62.93s
# Epoch 157/200, Train Loss: 1.6438, Train Acc: 57.21%, Test Loss: 1.4072, Test Acc: 80.66%, LR: 0.000100, Time: 62.95s
# Epoch 158/200, Train Loss: 1.6608, Train Acc: 59.21%, Test Loss: 1.4121, Test Acc: 80.73%, LR: 0.000100, Time: 62.96s
# Epoch 159/200, Train Loss: 1.6303, Train Acc: 57.25%, Test Loss: 1.4019, Test Acc: 80.69%, LR: 0.000100, Time: 63.03s
# Epoch 160/200, Train Loss: 1.6023, Train Acc: 58.25%, Test Loss: 1.4040, Test Acc: 80.85%, LR: 0.000100, Time: 62.99s
# Epoch 161/200, Train Loss: 1.6631, Train Acc: 56.40%, Test Loss: 1.3988, Test Acc: 81.06%, LR: 0.000100, Time: 63.02s
# Best model saved with accuracy: 81.06%
# Epoch 162/200, Train Loss: 1.6379, Train Acc: 56.78%, Test Loss: 1.4128, Test Acc: 80.61%, LR: 0.000100, Time: 63.03s
# Epoch 163/200, Train Loss: 1.6336, Train Acc: 57.83%, Test Loss: 1.4234, Test Acc: 80.63%, LR: 0.000100, Time: 62.99s
# Epoch 164/200, Train Loss: 1.6135, Train Acc: 58.35%, Test Loss: 1.4059, Test Acc: 80.88%, LR: 0.000100, Time: 62.98s
# Epoch 165/200, Train Loss: 1.6090, Train Acc: 57.93%, Test Loss: 1.3974, Test Acc: 80.98%, LR: 0.000100, Time: 63.07s
# Epoch 166/200, Train Loss: 1.6354, Train Acc: 58.07%, Test Loss: 1.3918, Test Acc: 81.02%, LR: 0.000100, Time: 63.05s
# Epoch 167/200, Train Loss: 1.6313, Train Acc: 57.87%, Test Loss: 1.4055, Test Acc: 80.96%, LR: 0.000100, Time: 63.06s
# Epoch 168/200, Train Loss: 1.6572, Train Acc: 56.81%, Test Loss: 1.4029, Test Acc: 80.83%, LR: 0.000100, Time: 63.13s
# Epoch 169/200, Train Loss: 1.6621, Train Acc: 59.92%, Test Loss: 1.3945, Test Acc: 81.10%, LR: 0.000100, Time: 62.94s
# Best model saved with accuracy: 81.10%
# Epoch 170/200, Train Loss: 1.6307, Train Acc: 57.17%, Test Loss: 1.4066, Test Acc: 80.71%, LR: 0.000100, Time: 62.92s
# Epoch 171/200, Train Loss: 1.6716, Train Acc: 58.47%, Test Loss: 1.4065, Test Acc: 81.07%, LR: 0.000100, Time: 62.98s
# Epoch 172/200, Train Loss: 1.6292, Train Acc: 59.63%, Test Loss: 1.3895, Test Acc: 81.30%, LR: 0.000100, Time: 62.95s
# Best model saved with accuracy: 81.30%
# Epoch 173/200, Train Loss: 1.5818, Train Acc: 59.07%, Test Loss: 1.4018, Test Acc: 80.96%, LR: 0.000100, Time: 62.95s
# Epoch 174/200, Train Loss: 1.6424, Train Acc: 56.40%, Test Loss: 1.3948, Test Acc: 80.99%, LR: 0.000100, Time: 62.99s
# Epoch 175/200, Train Loss: 1.6318, Train Acc: 56.37%, Test Loss: 1.3997, Test Acc: 81.01%, LR: 0.000100, Time: 62.96s
# Epoch 176/200, Train Loss: 1.5939, Train Acc: 59.56%, Test Loss: 1.3934, Test Acc: 81.19%, LR: 0.000100, Time: 63.01s
# Epoch 177/200, Train Loss: 1.6278, Train Acc: 58.34%, Test Loss: 1.4159, Test Acc: 81.05%, LR: 0.000100, Time: 63.06s
# Epoch 178/200, Train Loss: 1.6025, Train Acc: 58.70%, Test Loss: 1.4013, Test Acc: 80.82%, LR: 0.000100, Time: 63.15s
# Epoch 179/200, Train Loss: 1.5891, Train Acc: 59.13%, Test Loss: 1.4059, Test Acc: 80.89%, LR: 0.000100, Time: 63.19s
# Epoch 180/200, Train Loss: 1.6056, Train Acc: 58.58%, Test Loss: 1.4012, Test Acc: 81.09%, LR: 0.000100, Time: 63.24s
# Epoch 181/200, Train Loss: 1.6188, Train Acc: 57.03%, Test Loss: 1.4137, Test Acc: 80.86%, LR: 0.000100, Time: 63.30s
# Epoch 182/200, Train Loss: 1.6200, Train Acc: 58.38%, Test Loss: 1.4111, Test Acc: 80.90%, LR: 0.000100, Time: 63.31s
# Epoch 183/200, Train Loss: 1.6143, Train Acc: 58.64%, Test Loss: 1.3946, Test Acc: 81.15%, LR: 0.000100, Time: 63.36s
# Epoch 184/200, Train Loss: 1.5738, Train Acc: 59.97%, Test Loss: 1.4036, Test Acc: 81.08%, LR: 0.000100, Time: 63.41s
# Epoch 185/200, Train Loss: 1.6498, Train Acc: 57.57%, Test Loss: 1.4166, Test Acc: 80.89%, LR: 0.000100, Time: 63.43s
# Epoch 186/200, Train Loss: 1.6241, Train Acc: 59.30%, Test Loss: 1.3920, Test Acc: 81.06%, LR: 0.000100, Time: 63.38s
# Epoch 187/200, Train Loss: 1.5789, Train Acc: 61.60%, Test Loss: 1.3995, Test Acc: 81.01%, LR: 0.000100, Time: 63.32s
# Epoch 188/200, Train Loss: 1.5948, Train Acc: 56.00%, Test Loss: 1.4248, Test Acc: 80.52%, LR: 0.000100, Time: 63.31s
# Epoch 189/200, Train Loss: 1.5912, Train Acc: 60.11%, Test Loss: 1.3991, Test Acc: 80.91%, LR: 0.000100, Time: 63.39s
# Epoch 190/200, Train Loss: 1.6551, Train Acc: 57.22%, Test Loss: 1.3977, Test Acc: 80.93%, LR: 0.000100, Time: 63.29s
# Epoch 191/200, Train Loss: 1.6308, Train Acc: 56.10%, Test Loss: 1.4093, Test Acc: 81.06%, LR: 0.000100, Time: 63.26s
# Epoch 192/200, Train Loss: 1.6112, Train Acc: 59.26%, Test Loss: 1.4235, Test Acc: 80.71%, LR: 0.000100, Time: 63.30s
# Early stopping triggered at epoch 192
# Training completed in 202.45 minutes
# Best Test Accuracy: 81.30%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_size</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>best_acc</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇█████</td></tr><tr><td>epoch_time</td><td>█▇▄▃▂▃▃▂▂▃▂▂▃▃▃▂▂▂▂▂▄▂▂▃▂▃▆▆▄▄▂▂▂▂▁▁▂▃▅▅</td></tr><tr><td>lr</td><td>██████████▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>total_time</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▁▁▂▂▂▂▂▂▂▂▂▄▄▄▅▅▅▅▅▅▅▆▇▇▇▇▇▇▇▇▇█▇▇▇▇█▇▇</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▆▅▅▅▅▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▂▂▂▃▃▃▃▆▆▆▇▆▇▆▇▇▇▇████████████████████</td></tr><tr><td>val_loss</td><td>█▇▅▄▄▄▅▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_size</td><td>64</td></tr><tr><td>best_acc</td><td>81.3</td></tr><tr><td>epoch</td><td>192</td></tr><tr><td>epoch_time</td><td>63.29941</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>total_time</td><td>12146.76687</td></tr><tr><td>train_acc</td><td>59.26</td></tr><tr><td>train_loss</td><td>1.61122</td></tr><tr><td>val_acc</td><td>80.71</td></tr><tr><td>val_loss</td><td>1.4235</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fancy-sweep-1</strong> at: <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/c5qttuhi' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/c5qttuhi</a><br> View project at: <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251121_193504-c5qttuhi/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
