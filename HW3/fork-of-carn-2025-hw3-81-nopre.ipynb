# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# !nvidia-smi # test we are on GPU
# Out:
# Fri Nov 21 23:51:19 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %pip uninstall -y torch torchaudio torchvision
# %pip install torch==2.9.1 --index-url https://download.pytorch.org/whl/test/cu126 -q # 2.9.1 has Muon
# %pip install torchaudio==2.9.1 --index-url https://download.pytorch.org/whl/test/cu126 -q 

# %pip install torchvision==0.24.1+cu126 --index-url https://download.pytorch.org/whl/cu126 -q
#
# %pip install timm wandb==0.22.0 torchmetrics numpy tensorboard matplotlib -q #--no-deps -q # no-deps to avoid torch 2.8.0, but wandb needs newer vers
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Note: you may need to restart the kernel to use updated packages.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 138.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 184.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 135.0 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 56.4 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 74.4 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 108.7 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 100.5 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 54.2 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 43.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 57.9 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 102.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 124.5 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 195.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.0/833.0 MB 1.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 2.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 9.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 16.6 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.7.2 requires torchvision>=0.5, which is not installed.
# fastai 2.8.5 requires torchvision>=0.11, which is not installed.
# timm 1.0.19 requires torchvision, which is not installed.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.7 MB/s eta 0:00:00a 0:00:01
# Note: you may need to restart the kernel to use updated packages.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 60.1 MB/s eta 0:00:0000:0100:01
# Note: you may need to restart the kernel to use updated packages.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 68.9 MB/s eta 0:00:00:00:0100:01
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

import torch
from torch import nn, Tensor
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from torchvision.transforms import v2
from torch.backends import cudnn
from torch import GradScaler
from torch import optim
from tqdm import tqdm
import numpy as np
import pickle
import time

from torchvision.datasets import CIFAR10, CIFAR100, MNIST, OxfordIIITPet
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau
import timm

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wandb_key")
import wandb
wandb.login(key=secret_value_0)

import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: stefan-dorian-gavril (stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# 2025-11-21 23:55:20.436813: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763769320.624635      48 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763769320.680225      48 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py in tf()
#      41     try:
# ---> 42         from tensorboard.compat import notf  # noqa: F401
#      43     except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py in tf()
#      41     try:
# ---> 42         from tensorboard.compat import notf  # noqa: F401
#      43     except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py in tf()
#      41     try:
# ---> 42         from tensorboard.compat import notf  # noqa: F401
#      43     except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py in tf()
#      41     try:
# ---> 42         from tensorboard.compat import notf  # noqa: F401
#      43     except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py in tf()
#      41     try:
# ---> 42         from tensorboard.compat import notf  # noqa: F401
#      43     except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
print("Muon" in dir(torch.optim))
print(torch.__version__)
# Out:
# True
# 2.9.1+cu126

# %%
device = torch.accelerator.current_accelerator() if torch.accelerator.is_available() else torch.device("cpu")
enable_half = device.type != "cpu"
# scaler = torch.amp.GradScaler('cuda', enabled=enable_half)

print("Grad scaler is enabled:", enable_half)
print("Device:", device)
# Out:
# Grad scaler is enabled: True
# Device: cuda

# %%
batch_size_map = {
    "resnet18": 128,
    "resnet50": 64,
    "resnest14d": 32,
    "resnest26d": 16,
    "mlp": 256
}

# %%
class BatchSizeScheduler:
    def __init__(self, initial_batch_size, max_batch_size, step_size=30):
        self.initial_batch_size = initial_batch_size
        self.current_batch_size = initial_batch_size
        self.max_batch_size = max_batch_size
        self.step_size = step_size
        self.epoch = 0
    
    def step(self):
        self.epoch += 1
        if self.epoch % self.step_size == 0 and self.current_batch_size < self.max_batch_size:
            old_bs = self.current_batch_size
            self.current_batch_size = min(int(self.current_batch_size * 1.5), self.max_batch_size)
            if self.current_batch_size != old_bs:
                print(f"Batch size increased: {old_bs} → {self.current_batch_size}")
                return True
        return False
    
    def get_batch_size(self):
        return self.current_batch_size

# %%
def get_transforms(dataset, image_size, is_train=True, use_heavy_aug=False):
    if dataset == "MNIST":
        return v2.Compose([
            v2.ToImage(),
            v2.Resize(image_size),
            v2.ToDtype(torch.float32, scale=True),
        ])
    
    if dataset == "CIFAR10":
        mean = (0.4914, 0.4822, 0.4465)
        std = (0.2023, 0.1994, 0.2010)
    elif dataset == "CIFAR100":
        mean = (0.5071, 0.4865, 0.4409)
        std = (0.2009, 0.1984, 0.2023)
    else:  # OxfordIIITPet
        mean = (0.485, 0.456, 0.406)
        std = (0.229, 0.224, 0.225)
    
    if is_train:
        if image_size == 32:
            transforms_list = [
                v2.ToImage(),
                v2.RandomCrop(32, padding=4),
                v2.RandomHorizontalFlip(),
            ]
            if use_heavy_aug:
                transforms_list.append(v2.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3)))
            transforms_list.extend([
                v2.ToDtype(torch.float32, scale=True),
                v2.Normalize(mean, std)
            ])
            return v2.Compose(transforms_list)
        else:  # For pretrained models (224x224)
            transforms_list = [
                v2.ToImage(),
                v2.Resize(256),
                v2.RandomCrop(image_size),
                v2.RandomHorizontalFlip(),
            ]
            transforms_list.extend([
                v2.ColorJitter(0.4, 0.4, 0.4, 0.1),  
                v2.RandomErasing(p=0.25),            
            ])
            transforms_list.extend([
                v2.ToDtype(torch.float32, scale=True),
                v2.Normalize(mean, std)
            ])
            return v2.Compose(transforms_list)
    else:
        return v2.Compose([
            v2.ToImage(),
            v2.Resize(image_size),
            v2.CenterCrop(image_size),
            v2.ToDtype(torch.float32, scale=True),
            v2.Normalize(mean, std)
        ])

# %%
DATA_ROOT = "/kaggle/working/data"
os.makedirs(DATA_ROOT, exist_ok=True)

def get_data_loaders(dataset_name, image_size, batch_size, num_workers=2, pin_memory=True, use_heavy_aug=False):
    train_transforms = get_transforms(dataset_name, image_size, is_train=True, use_heavy_aug=use_heavy_aug)
    test_transform = get_transforms(dataset_name, image_size, is_train=False)

    if dataset_name == "CIFAR100":
        train_dataset= CIFAR100(root=DATA_ROOT, train=True, download=True, transform=train_transforms)
        test_dataset = CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transform)
    elif dataset_name == "CIFAR10":
        train_dataset= CIFAR10(root=DATA_ROOT, train=True, download=True, transform=train_transforms)
        test_dataset = CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transform)
    elif dataset_name == "MNIST":
        train_dataset= MNIST(root=DATA_ROOT, train=True, download=True, transform=train_transforms)
        test_dataset = MNIST(root=DATA_ROOT, train=False, download=True, transform=test_transform)
    elif dataset_name == "OxfordIIITPet":
        train_dataset= OxfordIIITPet(root=DATA_ROOT, download=True, transform=train_transforms)
        test_dataset = OxfordIIITPet(root=DATA_ROOT, split='test', download=True, transform=test_transform)
    else:
        raise ValueError(f"Unsupported dataset: {dataset_name}")
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
    return train_loader, test_loader

# %%
def get_num_classes(dataset_name):
    if dataset_name in ["CIFAR100"]:
        return 100
    elif dataset_name in ["CIFAR10"]:
        return 10
    elif dataset_name in ["MNIST"]:
        return 10
    elif dataset_name in ["OxfordIIITPet"]:
        return 37
    else:
        raise ValueError(f"Unsupported dataset: {dataset_name}")


ALLOWED_MODELS = ["resnet18", "resnet50", "resnest14d", "resnest26d", "mlp"]

# %%
def create_model(model_name, dataset_name, pretrained=False, image_size=32):
    if model_name not in ALLOWED_MODELS:
        raise ValueError(f"Unsupported model: {model_name}")
    
    num_classes=get_num_classes(dataset_name)

    if model_name == "mlp":
        in_channels = 1 if dataset_name == "MNIST" else 3
        return nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_channels * image_size * image_size, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
    else:
        model = timm.create_model(model_name, pretrained=pretrained, num_classes=num_classes)
        if not pretrained and image_size == 32:
            if model_name.startswith("resnet") or model_name.startswith("resnest"):
                model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
                model.maxpool = nn.Identity()
    return model

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, adaptive=False, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"
        self.rho = rho
        self.adaptive = adaptive

        defaults = dict(rho=rho, adaptive=adaptive, **kwargs)
        super(SAM, self).__init__(params, defaults)

        # Base optimizer instance
        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()

        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None:
                    continue
                e = (torch.pow(p, 2) if group["adaptive"] else 1.0) * p.grad * scale
                p.add_(e)  # ascent step
                self.state[p]["e"] = e

        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None:
                    continue
                p.sub_(self.state[p]["e"])  # restore weights

        self.base_optimizer.step()

        if zero_grad:
            self.zero_grad()

    def zero_grad(self):
        self.base_optimizer.zero_grad()

    def step(self):
        # Not used — SAM requires first_step + second_step manually
        raise RuntimeError("Use first_step() and second_step() with SAM.")
    
    def _grad_norm(self):
        norm = torch.norm(
            torch.stack([
                ((torch.pow(p, 2) if self.adaptive else 1.0) * p.grad).norm(p=2)
                for group in self.param_groups for p in group["params"]
                if p.grad is not None
            ]),
            p=2
        )
        return norm

def create_optimizer(optimizer_name, model, lr, weight_decay, pretrained):
    if optimizer_name == "SGD" and pretrained:
        param_groups = [
            {"params": [], "lr": lr * 0.25},
            {"params": [], "lr": lr * 0.5},
            {"params": [], "lr": lr * 1.0},
        ]

        for name, p in model.named_parameters():
            if not p.requires_grad:
                continue
            if "layer4" in name or "fc" in name:
                param_groups[2]["params"].append(p)
            elif "layer3" in name:
                param_groups[1]["params"].append(p)
            else:
                param_groups[0]["params"].append(p)

        return optim.SGD(param_groups, momentum=0.9, nesterov=True, weight_decay=weight_decay)
    
    elif optimizer_name == "SGD" and not pretrained:
        return optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay)
    elif optimizer_name == "AdamW":
        return optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_name == "Adam":
        return optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_name == "SAM":
        return SAM(model.parameters(), base_optimizer=optim.SGD, lr=lr, momentum=0.9, weight_decay=weight_decay)
    elif optimizer_name == "Muon":
        return torch.optim.Muon(model.parameters(), lr=lr, weight_decay=weight_decay)        
    else:
        raise ValueError(f"Unsupported optimizer: {optimizer_name}")

# %%
def create_scheduler(scheduler_name, optimizer, step_size=30):
    base_optimizer = optimizer.base_optimizer if isinstance(optimizer, SAM) else optimizer

    if scheduler_name == "StepLR":
        return StepLR(base_optimizer, step_size=step_size, gamma=0.1)
    elif scheduler_name == "ReduceLROnPlateau":
        return ReduceLROnPlateau(base_optimizer, patience=5)
    else:
        raise ValueError(f"Unsupported scheduler: {scheduler_name}")

# %%
def train_epoch(model, train_loader, criterion, optimizer, scaler, device, use_amp, 
                mixup_cutmix_transform=None):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        if mixup_cutmix_transform is not None:
            inputs, targets = mixup_cutmix_transform(inputs, targets)

        with torch.amp.autocast(device_type=device.type, enabled=use_amp):
            outputs = model(inputs)
            loss = criterion(outputs, targets)

        if isinstance(optimizer, SAM):
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer.base_optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.first_step(zero_grad=True)

            with torch.amp.autocast(device_type=device.type, enabled=use_amp):
                outputs = model(inputs)
                loss = criterion(outputs, targets)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer.base_optimizer)
            scaler.step(optimizer.base_optimizer)
            scaler.update()
            optimizer.zero_grad()
        else: 
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update() 
            optimizer.zero_grad()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        if targets.dim() > 1:  # Mixed labels (one-hot/ soft labels)
            correct += predicted.eq(targets.argmax(1)).sum().item()
        else:  # Regular 
            correct += predicted.eq(targets).sum().item()

    return train_loss / len(train_loader), 100.0 * correct/total


def test(model, test_loader, criterion, device, use_amp):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            with torch.amp.autocast(device_type=device.type, enabled=use_amp):
                outputs = model(inputs)
                loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    return test_loss / len(test_loader), 100.0 * correct/total


def train_model(config):
    label_smoothing = config.get("label_smoothing", 0.0)
    criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
    scaler = torch.amp.GradScaler(device.type, enabled=config["use_amp"])
    writer = SummaryWriter(log_dir=f'./logs/{config["dataset"]}/{config["optimizer"]}_{config["model"]}_bs{batch_size_map[config["model"]]}_lr{config["lr"]}_sched{config["scheduler"]}')

    image_size = 224 if config["pretrained"] else 32
    initial_batch_size = batch_size_map[config["model"]]
    
    use_bs_scheduler = config.get("use_batch_size_scheduler", False)
    if use_bs_scheduler:
        bs_scheduler = BatchSizeScheduler(
            initial_batch_size=initial_batch_size // 2, 
            max_batch_size=initial_batch_size,
            step_size=30
        )
        batch_size = bs_scheduler.get_batch_size()
        print(f"Batch size scheduler enabled: {batch_size} → {initial_batch_size}")
    else:
        batch_size = initial_batch_size

    use_heavy_aug = config.get("use_heavy_aug", False)
    train_loader, test_loader = get_data_loaders(config["dataset"], image_size, batch_size, config["num_workers"], config["pin_memory"], use_heavy_aug=use_heavy_aug) 
    model = create_model(config["model"], config["dataset"], config["pretrained"], image_size)
    model.to(device)

    if config.get("use_compile", False) and hasattr(torch, "compile"):
        print("Compiliing is enabled")
        try:
            model = torch.compile(model)
        except Exception as e:
            print(f"Compiling failed: {e}.")
            
    optimizer = create_optimizer(config["optimizer"], model, config["lr"], config["weight_decay"], config["pretrained"])
    
    step_size = config.get("step_size", 30)
    scheduler = create_scheduler(config["scheduler"], optimizer, step_size=step_size)

    epochs = config["epochs"]
    
    best_acc = 0.0
    best_acc_epoch = None
    counter = 0
    patience = config.get("patience", 10)

    mixup_cutmix_transform = None
    use_mixup = config.get("use_mixup", False)
    use_cutmix = config.get("use_cutmix", False)
    
    if use_mixup or use_cutmix:
        num_classes = get_num_classes(config["dataset"])
        transforms_list = []
        
        if use_mixup:
            mixup_alpha = config.get("mixup_alpha", 0.2)
            transforms_list.append(v2.MixUp(alpha=mixup_alpha, num_classes=num_classes))
        
        if use_cutmix:
            cutmix_alpha = config.get("cutmix_alpha", 0.2)
            transforms_list.append(v2.CutMix(alpha=cutmix_alpha, num_classes=num_classes))
        
        if len(transforms_list) > 1:
            mixup_cutmix_transform = v2.RandomChoice(transforms_list)
        else:
            mixup_cutmix_transform = transforms_list[0]

    start_time = time.time()
    print("Start training")
    
    for epoch in range(epochs):
        epoch_start = time.time()

        if use_bs_scheduler and bs_scheduler.step():
            batch_size = bs_scheduler.get_batch_size()
            train_loader, test_loader = get_data_loaders(
                config["dataset"], 
                image_size, 
                batch_size,
                config.get("num_workers", 2),
                config.get("pin_memory", True),
                use_heavy_aug=use_heavy_aug
            )

        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, scaler, device, config["use_amp"],
                                           mixup_cutmix_transform=mixup_cutmix_transform)
        test_loss, test_acc = test(model, test_loader, criterion, device, config["use_amp"])

        if isinstance(scheduler, StepLR):
            scheduler.step()
        elif isinstance(scheduler, ReduceLROnPlateau):
            scheduler.step(test_loss)
        
        if isinstance(optimizer, SAM):
            current_lr = optimizer.base_optimizer.param_groups[0]['lr']
        else:
            current_lr = optimizer.param_groups[0]['lr']
        
        epoch_time = time.time() - epoch_start

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%, LR: {current_lr:.6f}, Time: {epoch_time:.2f}s")
        
        if config["use_wandb"]:
            wandb.log({
                "epoch": epoch + 1,
                "train_loss": train_loss,
                "train_acc": train_acc,
                "val_loss": test_loss,
                "val_acc": test_acc,
                "lr": current_lr,
                "epoch_time": epoch_time,
                "batch_size": batch_size if use_bs_scheduler else initial_batch_size
            })

        writer.add_scalar('Loss/Train', train_loss, epoch)
        writer.add_scalar('Loss/Test', test_loss, epoch)
        writer.add_scalar('Accuracy/Train', train_acc, epoch)
        writer.add_scalar('Accuracy/Test', test_acc, epoch)
        writer.add_scalar('Learning Rate', current_lr, epoch)
        if use_bs_scheduler:
            writer.add_scalar('Batch_Size', batch_size, epoch)
        
        if test_acc > best_acc:
            best_acc = test_acc
            os.makedirs('./checkpoints', exist_ok=True)

            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_acc': best_acc,    
                'config': config    
            }, f'./checkpoints/{config["optimizer"]}_{config["model"]}_bs{batch_size_map[config["model"]]}_lr{config["lr"]}_sched{config["scheduler"]}.pth')
            print(f"Best model saved with accuracy: {best_acc:.2f}%")

        # Early stop mechanism
        if best_acc_epoch is None:
            best_acc_epoch = test_acc
        elif test_acc <= best_acc_epoch:
            counter += 1
            if counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                break
        else:
            best_acc_epoch = test_acc
            counter = 0

    total_time = time.time() - start_time
    print(f"Training completed in {total_time/60:.2f} minutes")
    print(f"Best Test Accuracy: {best_acc:.2f}%")
    
    writer.close()

    if config["use_wandb"]:
        wandb.log({
            "best_acc": best_acc,
            "total_time": total_time
        })

    return {
        'best_acc': best_acc,
        'total_time': total_time,
        'final_train_acc': train_acc,
        'final_test_acc': test_acc
    }

# %%
def create_sweep_config(pretrained=False):
    if pretrained:
        return {
            "method": "grid",
            "metric": {"name": "val_acc", "goal": "maximize"},
            "parameters": {
                "dataset": {"value": "CIFAR100"},
                "model": {"values": ["resnet18", "resnet50"]},
                "pretrained": {"value": True}, 
                "lr": {"values": [3e-4, 1e-4]},
                "optimizer": {"value": "AdamW"},  
                "scheduler": {"value": "StepLR"},  
                "epochs": {"value": 100},
                "weight_decay": {"value": 1e-2},
                "num_workers": {"value": 2},  
                "pin_memory": {"value": True},
                "use_amp": {"value": True},  
                "use_wandb": {"value": True},
                "use_batch_size_scheduler": {"value": False}
            }
        }
    else:
        return {
            "method": "grid",
            "metric": {"name": "val_acc", "goal": "maximize"},
            "parameters": {
                "dataset": {"value": "CIFAR100"},
                "model": {"values": ["resnet50"]},
                "pretrained": {"value": False}, 
                "lr": {"values": [0.1]},  
                "optimizer": {"values": ["SGD"]},
                "scheduler": {"value": "StepLR"},
                "step_size": {"value": 50},
                "epochs": {"value": 200},
                "weight_decay": {"value": 5e-4},
                "num_workers": {"value": 2}, 
                "pin_memory": {"value": True},
                "use_amp": {"value": True}, 
                "use_wandb": {"value": True},
                "use_batch_size_scheduler": {"value": False},
                "use_heavy_aug": {"value": True},
                "use_mixup": {"value": True},
                "mixup_alpha": {"value": 0.2},
                "use_cutmix": {"value": True},
                "cutmix_alpha": {"value": 0.2},
                "label_smoothing": {"value": 0.1},
                "patience": {"value": 20}
            }
        }

# %%
def sweep_train():
    run = wandb.init(project="training_pipeline")
    cfg = dict(wandb.config)
    results = train_model(cfg)
    run.finish()

# %%
sweep_config = create_sweep_config(pretrained=False)
sweep_id = wandb.sweep(sweep_config, project="training_pipeline")
wandb.agent(sweep_id, function=sweep_train)
# Out:
# Create sweep with ID: zwxey7sn
# Sweep URL: https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/zwxey7sn
# wandb: Agent Starting Run: dhzy6s4r with config:
# wandb: 	cutmix_alpha: 0.2
# wandb: 	dataset: CIFAR100
# wandb: 	epochs: 200
# wandb: 	label_smoothing: 0.1
# wandb: 	lr: 0.1
# wandb: 	mixup_alpha: 0.2
# wandb: 	model: resnet50
# wandb: 	num_workers: 2
# wandb: 	optimizer: SGD
# wandb: 	patience: 20
# wandb: 	pin_memory: True
# wandb: 	pretrained: False
# wandb: 	scheduler: StepLR
# wandb: 	step_size: 50
# wandb: 	use_amp: True
# wandb: 	use_batch_size_scheduler: False
# wandb: 	use_cutmix: True
# wandb: 	use_heavy_aug: True
# wandb: 	use_mixup: True
# wandb: 	use_wandb: True
# wandb: 	weight_decay: 0.0005
# Ignoring project 'training_pipeline' when running a sweep.
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20251121_235539-dhzy6s4r</code>
# Syncing run <strong><a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/dhzy6s4r' target="_blank">sandy-sweep-1</a></strong> to <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/zwxey7sn' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/zwxey7sn</a>
#  View project at <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline</a>
#  View sweep at <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/zwxey7sn' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/sweeps/zwxey7sn</a>
#  View run at <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/dhzy6s4r' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/dhzy6s4r</a>
# 100%|██████████| 169M/169M [00:02<00:00, 80.3MB/s]
# Start training
# Epoch 1/200, Train Loss: 4.3385, Train Acc: 6.30%, Test Loss: 3.9940, Test Acc: 10.23%, LR: 0.100000, Time: 66.31s
# Best model saved with accuracy: 10.23%
# Epoch 2/200, Train Loss: 4.0810, Train Acc: 10.50%, Test Loss: 3.7215, Test Acc: 15.68%, LR: 0.100000, Time: 68.69s
# Best model saved with accuracy: 15.68%
# Epoch 3/200, Train Loss: 3.8531, Train Acc: 15.96%, Test Loss: 3.5940, Test Acc: 20.17%, LR: 0.100000, Time: 69.12s
# Best model saved with accuracy: 20.17%
# Epoch 4/200, Train Loss: 3.6377, Train Acc: 21.35%, Test Loss: 3.5570, Test Acc: 18.72%, LR: 0.100000, Time: 69.34s
# Epoch 5/200, Train Loss: 3.5104, Train Acc: 24.87%, Test Loss: 2.9840, Test Acc: 32.65%, LR: 0.100000, Time: 69.18s
# Best model saved with accuracy: 32.65%
# Epoch 6/200, Train Loss: 3.4195, Train Acc: 26.91%, Test Loss: 3.1500, Test Acc: 29.99%, LR: 0.100000, Time: 69.41s
# Epoch 7/200, Train Loss: 3.3636, Train Acc: 29.01%, Test Loss: 3.1981, Test Acc: 30.68%, LR: 0.100000, Time: 69.40s
# Epoch 8/200, Train Loss: 3.3463, Train Acc: 30.11%, Test Loss: 2.9233, Test Acc: 34.66%, LR: 0.100000, Time: 69.19s
# Best model saved with accuracy: 34.66%
# Epoch 9/200, Train Loss: 3.2748, Train Acc: 31.30%, Test Loss: 2.9398, Test Acc: 33.58%, LR: 0.100000, Time: 69.22s
# Epoch 10/200, Train Loss: 3.2969, Train Acc: 31.39%, Test Loss: 2.7599, Test Acc: 38.45%, LR: 0.100000, Time: 69.27s
# Best model saved with accuracy: 38.45%
# Epoch 11/200, Train Loss: 3.2217, Train Acc: 33.02%, Test Loss: 2.9514, Test Acc: 33.73%, LR: 0.100000, Time: 69.24s
# Epoch 12/200, Train Loss: 3.2149, Train Acc: 33.38%, Test Loss: 3.0008, Test Acc: 35.40%, LR: 0.100000, Time: 69.28s
# Epoch 13/200, Train Loss: 3.1832, Train Acc: 34.29%, Test Loss: 2.7588, Test Acc: 39.36%, LR: 0.100000, Time: 69.31s
# Best model saved with accuracy: 39.36%
# Epoch 14/200, Train Loss: 3.1968, Train Acc: 34.46%, Test Loss: 2.8136, Test Acc: 38.54%, LR: 0.100000, Time: 69.32s
# Epoch 15/200, Train Loss: 3.1916, Train Acc: 34.69%, Test Loss: 2.7229, Test Acc: 39.92%, LR: 0.100000, Time: 69.31s
# Best model saved with accuracy: 39.92%
# Epoch 16/200, Train Loss: 3.1535, Train Acc: 35.72%, Test Loss: 2.7304, Test Acc: 39.29%, LR: 0.100000, Time: 69.31s
# Epoch 17/200, Train Loss: 3.1338, Train Acc: 35.99%, Test Loss: 2.6991, Test Acc: 41.66%, LR: 0.100000, Time: 69.29s
# Best model saved with accuracy: 41.66%
# Epoch 18/200, Train Loss: 3.1102, Train Acc: 37.21%, Test Loss: 2.7518, Test Acc: 40.96%, LR: 0.100000, Time: 69.29s
# Epoch 19/200, Train Loss: 3.0926, Train Acc: 37.47%, Test Loss: 3.0110, Test Acc: 35.25%, LR: 0.100000, Time: 69.30s
# Epoch 20/200, Train Loss: 3.0838, Train Acc: 37.50%, Test Loss: 2.8867, Test Acc: 37.20%, LR: 0.100000, Time: 69.28s
# Epoch 21/200, Train Loss: 3.0582, Train Acc: 38.30%, Test Loss: 2.8327, Test Acc: 38.88%, LR: 0.100000, Time: 69.31s
# Epoch 22/200, Train Loss: 3.0584, Train Acc: 38.56%, Test Loss: 2.6292, Test Acc: 43.61%, LR: 0.100000, Time: 69.41s
# Best model saved with accuracy: 43.61%
# Epoch 23/200, Train Loss: 3.0837, Train Acc: 38.03%, Test Loss: 2.9722, Test Acc: 34.99%, LR: 0.100000, Time: 69.30s
# Epoch 24/200, Train Loss: 3.0420, Train Acc: 38.90%, Test Loss: 2.7691, Test Acc: 40.79%, LR: 0.100000, Time: 69.28s
# Epoch 25/200, Train Loss: 3.0261, Train Acc: 39.61%, Test Loss: 2.5360, Test Acc: 45.66%, LR: 0.100000, Time: 69.28s
# Best model saved with accuracy: 45.66%
# Epoch 26/200, Train Loss: 3.0467, Train Acc: 39.44%, Test Loss: 2.8164, Test Acc: 40.66%, LR: 0.100000, Time: 69.28s
# Epoch 27/200, Train Loss: 3.0077, Train Acc: 39.63%, Test Loss: 2.9705, Test Acc: 37.22%, LR: 0.100000, Time: 69.27s
# Epoch 28/200, Train Loss: 2.9804, Train Acc: 40.30%, Test Loss: 2.5258, Test Acc: 46.09%, LR: 0.100000, Time: 69.23s
# Best model saved with accuracy: 46.09%
# Epoch 29/200, Train Loss: 3.0514, Train Acc: 39.53%, Test Loss: 2.8940, Test Acc: 39.32%, LR: 0.100000, Time: 69.26s
# Epoch 30/200, Train Loss: 3.0164, Train Acc: 40.00%, Test Loss: 2.7486, Test Acc: 39.88%, LR: 0.100000, Time: 69.27s
# Epoch 31/200, Train Loss: 3.0317, Train Acc: 39.83%, Test Loss: 2.7739, Test Acc: 40.47%, LR: 0.100000, Time: 69.26s
# Epoch 32/200, Train Loss: 3.0150, Train Acc: 40.07%, Test Loss: 2.4488, Test Acc: 47.86%, LR: 0.100000, Time: 69.22s
# Best model saved with accuracy: 47.86%
# Epoch 33/200, Train Loss: 2.9986, Train Acc: 40.57%, Test Loss: 2.5731, Test Acc: 44.67%, LR: 0.100000, Time: 69.23s
# Epoch 34/200, Train Loss: 2.9399, Train Acc: 41.62%, Test Loss: 2.7524, Test Acc: 41.50%, LR: 0.100000, Time: 69.26s
# Epoch 35/200, Train Loss: 3.0146, Train Acc: 40.35%, Test Loss: 2.4520, Test Acc: 47.67%, LR: 0.100000, Time: 69.22s
# Epoch 36/200, Train Loss: 2.9546, Train Acc: 41.35%, Test Loss: 2.5250, Test Acc: 45.62%, LR: 0.100000, Time: 69.10s
# Epoch 37/200, Train Loss: 3.0059, Train Acc: 40.43%, Test Loss: 2.7800, Test Acc: 40.50%, LR: 0.100000, Time: 69.17s
# Epoch 38/200, Train Loss: 3.0109, Train Acc: 40.45%, Test Loss: 2.4352, Test Acc: 48.06%, LR: 0.100000, Time: 69.16s
# Best model saved with accuracy: 48.06%
# Epoch 39/200, Train Loss: 3.0088, Train Acc: 40.41%, Test Loss: 2.7121, Test Acc: 42.04%, LR: 0.100000, Time: 69.18s
# Epoch 40/200, Train Loss: 2.9720, Train Acc: 41.38%, Test Loss: 2.6098, Test Acc: 42.99%, LR: 0.100000, Time: 69.17s
# Epoch 41/200, Train Loss: 2.9591, Train Acc: 41.34%, Test Loss: 2.5126, Test Acc: 46.03%, LR: 0.100000, Time: 69.21s
# Epoch 42/200, Train Loss: 2.9748, Train Acc: 41.06%, Test Loss: 2.7340, Test Acc: 41.57%, LR: 0.100000, Time: 69.36s
# Epoch 43/200, Train Loss: 3.0046, Train Acc: 40.71%, Test Loss: 2.6767, Test Acc: 42.27%, LR: 0.100000, Time: 69.25s
# Epoch 44/200, Train Loss: 2.9606, Train Acc: 41.09%, Test Loss: 2.5391, Test Acc: 45.90%, LR: 0.100000, Time: 69.18s
# Epoch 45/200, Train Loss: 2.9695, Train Acc: 41.56%, Test Loss: 2.5826, Test Acc: 44.54%, LR: 0.100000, Time: 69.17s
# Epoch 46/200, Train Loss: 2.9677, Train Acc: 41.68%, Test Loss: 3.1172, Test Acc: 36.77%, LR: 0.100000, Time: 69.19s
# Epoch 47/200, Train Loss: 2.9941, Train Acc: 40.77%, Test Loss: 2.6478, Test Acc: 42.09%, LR: 0.100000, Time: 69.15s
# Epoch 48/200, Train Loss: 2.9671, Train Acc: 41.44%, Test Loss: 2.4648, Test Acc: 47.67%, LR: 0.100000, Time: 69.15s
# Epoch 49/200, Train Loss: 2.9467, Train Acc: 41.80%, Test Loss: 2.7738, Test Acc: 42.18%, LR: 0.100000, Time: 69.33s
# Epoch 50/200, Train Loss: 2.9385, Train Acc: 42.21%, Test Loss: 2.5242, Test Acc: 45.65%, LR: 0.010000, Time: 69.08s
# Epoch 51/200, Train Loss: 2.5605, Train Acc: 54.12%, Test Loss: 1.8141, Test Acc: 66.26%, LR: 0.010000, Time: 69.11s
# Best model saved with accuracy: 66.26%
# Epoch 52/200, Train Loss: 2.4928, Train Acc: 56.81%, Test Loss: 1.7733, Test Acc: 68.34%, LR: 0.010000, Time: 69.10s
# Best model saved with accuracy: 68.34%
# Epoch 53/200, Train Loss: 2.4652, Train Acc: 57.70%, Test Loss: 1.7559, Test Acc: 68.35%, LR: 0.010000, Time: 69.27s
# Best model saved with accuracy: 68.35%
# Epoch 54/200, Train Loss: 2.4121, Train Acc: 59.66%, Test Loss: 1.7140, Test Acc: 69.84%, LR: 0.010000, Time: 69.38s
# Best model saved with accuracy: 69.84%
# Epoch 55/200, Train Loss: 2.4191, Train Acc: 59.88%, Test Loss: 1.7176, Test Acc: 69.19%, LR: 0.010000, Time: 69.20s
# Epoch 56/200, Train Loss: 2.3576, Train Acc: 60.92%, Test Loss: 1.6976, Test Acc: 70.42%, LR: 0.010000, Time: 69.19s
# Best model saved with accuracy: 70.42%
# Epoch 57/200, Train Loss: 2.3591, Train Acc: 60.72%, Test Loss: 1.6872, Test Acc: 70.20%, LR: 0.010000, Time: 69.20s
# Epoch 58/200, Train Loss: 2.3250, Train Acc: 61.44%, Test Loss: 1.7047, Test Acc: 69.85%, LR: 0.010000, Time: 69.16s
# Epoch 59/200, Train Loss: 2.3285, Train Acc: 61.74%, Test Loss: 1.6627, Test Acc: 71.28%, LR: 0.010000, Time: 69.28s
# Best model saved with accuracy: 71.28%
# Epoch 60/200, Train Loss: 2.2721, Train Acc: 63.28%, Test Loss: 1.6806, Test Acc: 70.39%, LR: 0.010000, Time: 69.26s
# Epoch 61/200, Train Loss: 2.3552, Train Acc: 61.95%, Test Loss: 1.7205, Test Acc: 69.84%, LR: 0.010000, Time: 69.13s
# Epoch 62/200, Train Loss: 2.3156, Train Acc: 62.92%, Test Loss: 1.6944, Test Acc: 70.22%, LR: 0.010000, Time: 69.14s
# Epoch 63/200, Train Loss: 2.3011, Train Acc: 62.72%, Test Loss: 1.6962, Test Acc: 70.11%, LR: 0.010000, Time: 69.20s
# Epoch 64/200, Train Loss: 2.2834, Train Acc: 63.31%, Test Loss: 1.7048, Test Acc: 70.23%, LR: 0.010000, Time: 69.06s
# Epoch 65/200, Train Loss: 2.2959, Train Acc: 63.26%, Test Loss: 1.7266, Test Acc: 69.60%, LR: 0.010000, Time: 69.00s
# Epoch 66/200, Train Loss: 2.2926, Train Acc: 62.91%, Test Loss: 1.6900, Test Acc: 70.83%, LR: 0.010000, Time: 69.02s
# Epoch 67/200, Train Loss: 2.2771, Train Acc: 63.80%, Test Loss: 1.7002, Test Acc: 70.21%, LR: 0.010000, Time: 69.05s
# Epoch 68/200, Train Loss: 2.2633, Train Acc: 63.61%, Test Loss: 1.7250, Test Acc: 69.79%, LR: 0.010000, Time: 69.03s
# Epoch 69/200, Train Loss: 2.2253, Train Acc: 64.65%, Test Loss: 1.7237, Test Acc: 70.07%, LR: 0.010000, Time: 69.06s
# Epoch 70/200, Train Loss: 2.2271, Train Acc: 64.35%, Test Loss: 1.6945, Test Acc: 70.38%, LR: 0.010000, Time: 69.08s
# Epoch 71/200, Train Loss: 2.2143, Train Acc: 64.80%, Test Loss: 1.6933, Test Acc: 70.93%, LR: 0.010000, Time: 69.09s
# Epoch 72/200, Train Loss: 2.2478, Train Acc: 64.26%, Test Loss: 1.7044, Test Acc: 70.66%, LR: 0.010000, Time: 69.09s
# Epoch 73/200, Train Loss: 2.2692, Train Acc: 63.89%, Test Loss: 1.7032, Test Acc: 70.64%, LR: 0.010000, Time: 69.05s
# Epoch 74/200, Train Loss: 2.2674, Train Acc: 64.73%, Test Loss: 1.6750, Test Acc: 70.86%, LR: 0.010000, Time: 69.09s
# Epoch 75/200, Train Loss: 2.2602, Train Acc: 64.78%, Test Loss: 1.6951, Test Acc: 70.05%, LR: 0.010000, Time: 69.11s
# Epoch 76/200, Train Loss: 2.2383, Train Acc: 64.80%, Test Loss: 1.7026, Test Acc: 70.54%, LR: 0.010000, Time: 69.10s
# Epoch 77/200, Train Loss: 2.2530, Train Acc: 64.42%, Test Loss: 1.7254, Test Acc: 69.71%, LR: 0.010000, Time: 69.09s
# Epoch 78/200, Train Loss: 2.2060, Train Acc: 65.60%, Test Loss: 1.6754, Test Acc: 71.29%, LR: 0.010000, Time: 69.10s
# Best model saved with accuracy: 71.29%
# Epoch 79/200, Train Loss: 2.2508, Train Acc: 65.34%, Test Loss: 1.6918, Test Acc: 70.77%, LR: 0.010000, Time: 69.06s
# Epoch 80/200, Train Loss: 2.1960, Train Acc: 66.14%, Test Loss: 1.6594, Test Acc: 72.22%, LR: 0.010000, Time: 69.15s
# Best model saved with accuracy: 72.22%
# Epoch 81/200, Train Loss: 2.1912, Train Acc: 65.81%, Test Loss: 1.6736, Test Acc: 71.29%, LR: 0.010000, Time: 69.17s
# Epoch 82/200, Train Loss: 2.2135, Train Acc: 65.71%, Test Loss: 1.6756, Test Acc: 70.81%, LR: 0.010000, Time: 69.11s
# Epoch 83/200, Train Loss: 2.2423, Train Acc: 64.83%, Test Loss: 1.6663, Test Acc: 71.67%, LR: 0.010000, Time: 69.02s
# Epoch 84/200, Train Loss: 2.2041, Train Acc: 65.78%, Test Loss: 1.7200, Test Acc: 69.86%, LR: 0.010000, Time: 69.13s
# Epoch 85/200, Train Loss: 2.1753, Train Acc: 66.37%, Test Loss: 1.6571, Test Acc: 71.80%, LR: 0.010000, Time: 69.13s
# Epoch 86/200, Train Loss: 2.2161, Train Acc: 65.66%, Test Loss: 1.6267, Test Acc: 72.87%, LR: 0.010000, Time: 69.16s
# Best model saved with accuracy: 72.87%
# Epoch 87/200, Train Loss: 2.1570, Train Acc: 66.94%, Test Loss: 1.7069, Test Acc: 70.17%, LR: 0.010000, Time: 69.07s
# Epoch 88/200, Train Loss: 2.1939, Train Acc: 66.34%, Test Loss: 1.6844, Test Acc: 71.50%, LR: 0.010000, Time: 69.12s
# Epoch 89/200, Train Loss: 2.1749, Train Acc: 67.03%, Test Loss: 1.6667, Test Acc: 71.80%, LR: 0.010000, Time: 69.13s
# Epoch 90/200, Train Loss: 2.1588, Train Acc: 67.56%, Test Loss: 1.7268, Test Acc: 69.60%, LR: 0.010000, Time: 69.12s
# Epoch 91/200, Train Loss: 2.1608, Train Acc: 67.17%, Test Loss: 1.6840, Test Acc: 70.95%, LR: 0.010000, Time: 69.06s
# Epoch 92/200, Train Loss: 2.2073, Train Acc: 66.02%, Test Loss: 1.6548, Test Acc: 72.32%, LR: 0.010000, Time: 69.11s
# Epoch 93/200, Train Loss: 2.1599, Train Acc: 67.22%, Test Loss: 1.6929, Test Acc: 71.74%, LR: 0.010000, Time: 69.03s
# Epoch 94/200, Train Loss: 2.1444, Train Acc: 67.69%, Test Loss: 1.6901, Test Acc: 70.76%, LR: 0.010000, Time: 69.08s
# Epoch 95/200, Train Loss: 2.1667, Train Acc: 67.21%, Test Loss: 1.6477, Test Acc: 72.34%, LR: 0.010000, Time: 69.08s
# Epoch 96/200, Train Loss: 2.1122, Train Acc: 68.34%, Test Loss: 1.6560, Test Acc: 71.92%, LR: 0.010000, Time: 69.18s
# Epoch 97/200, Train Loss: 2.1554, Train Acc: 67.85%, Test Loss: 1.6703, Test Acc: 71.97%, LR: 0.010000, Time: 69.12s
# Epoch 98/200, Train Loss: 2.1618, Train Acc: 67.78%, Test Loss: 1.6758, Test Acc: 71.46%, LR: 0.010000, Time: 68.99s
# Epoch 99/200, Train Loss: 2.1701, Train Acc: 67.34%, Test Loss: 1.6486, Test Acc: 72.74%, LR: 0.010000, Time: 69.08s
# Epoch 100/200, Train Loss: 2.1516, Train Acc: 67.14%, Test Loss: 1.6553, Test Acc: 72.66%, LR: 0.001000, Time: 69.08s
# Epoch 101/200, Train Loss: 1.9565, Train Acc: 74.35%, Test Loss: 1.4445, Test Acc: 78.60%, LR: 0.001000, Time: 68.93s
# Best model saved with accuracy: 78.60%
# Epoch 102/200, Train Loss: 1.9043, Train Acc: 76.24%, Test Loss: 1.4650, Test Acc: 78.65%, LR: 0.001000, Time: 68.91s
# Best model saved with accuracy: 78.65%
# Epoch 103/200, Train Loss: 1.8707, Train Acc: 77.63%, Test Loss: 1.4091, Test Acc: 79.53%, LR: 0.001000, Time: 69.01s
# Best model saved with accuracy: 79.53%
# Epoch 104/200, Train Loss: 1.8602, Train Acc: 78.20%, Test Loss: 1.4324, Test Acc: 79.22%, LR: 0.001000, Time: 69.01s
# Epoch 105/200, Train Loss: 1.8266, Train Acc: 79.23%, Test Loss: 1.4120, Test Acc: 79.63%, LR: 0.001000, Time: 69.01s
# Best model saved with accuracy: 79.63%
# Epoch 106/200, Train Loss: 1.8476, Train Acc: 78.69%, Test Loss: 1.4199, Test Acc: 79.61%, LR: 0.001000, Time: 69.21s
# Epoch 107/200, Train Loss: 1.8569, Train Acc: 78.43%, Test Loss: 1.4015, Test Acc: 79.90%, LR: 0.001000, Time: 69.60s
# Best model saved with accuracy: 79.90%
# Epoch 108/200, Train Loss: 1.8338, Train Acc: 78.62%, Test Loss: 1.4026, Test Acc: 79.95%, LR: 0.001000, Time: 69.55s
# Best model saved with accuracy: 79.95%
# Epoch 109/200, Train Loss: 1.8505, Train Acc: 79.26%, Test Loss: 1.4086, Test Acc: 79.98%, LR: 0.001000, Time: 70.03s
# Best model saved with accuracy: 79.98%
# Epoch 110/200, Train Loss: 1.8324, Train Acc: 79.48%, Test Loss: 1.4025, Test Acc: 80.24%, LR: 0.001000, Time: 69.43s
# Best model saved with accuracy: 80.24%
# Epoch 111/200, Train Loss: 1.8145, Train Acc: 79.78%, Test Loss: 1.3897, Test Acc: 80.59%, LR: 0.001000, Time: 69.43s
# Best model saved with accuracy: 80.59%
# Epoch 112/200, Train Loss: 1.8258, Train Acc: 79.71%, Test Loss: 1.4319, Test Acc: 80.01%, LR: 0.001000, Time: 70.51s
# Epoch 113/200, Train Loss: 1.8174, Train Acc: 80.24%, Test Loss: 1.4064, Test Acc: 80.16%, LR: 0.001000, Time: 70.04s
# Epoch 114/200, Train Loss: 1.8139, Train Acc: 80.13%, Test Loss: 1.4116, Test Acc: 80.03%, LR: 0.001000, Time: 70.30s
# Epoch 115/200, Train Loss: 1.7634, Train Acc: 80.79%, Test Loss: 1.3963, Test Acc: 80.23%, LR: 0.001000, Time: 70.12s
# Epoch 116/200, Train Loss: 1.7451, Train Acc: 81.83%, Test Loss: 1.3916, Test Acc: 80.51%, LR: 0.001000, Time: 68.97s
# Epoch 117/200, Train Loss: 1.7639, Train Acc: 80.90%, Test Loss: 1.4002, Test Acc: 80.31%, LR: 0.001000, Time: 68.95s
# Epoch 118/200, Train Loss: 1.7789, Train Acc: 81.24%, Test Loss: 1.3938, Test Acc: 80.66%, LR: 0.001000, Time: 68.99s
# Best model saved with accuracy: 80.66%
# Epoch 119/200, Train Loss: 1.7333, Train Acc: 81.78%, Test Loss: 1.4235, Test Acc: 79.87%, LR: 0.001000, Time: 69.02s
# Epoch 120/200, Train Loss: 1.7710, Train Acc: 81.06%, Test Loss: 1.4129, Test Acc: 79.87%, LR: 0.001000, Time: 69.01s
# Epoch 121/200, Train Loss: 1.7297, Train Acc: 81.54%, Test Loss: 1.4017, Test Acc: 80.11%, LR: 0.001000, Time: 69.05s
# Epoch 122/200, Train Loss: 1.7291, Train Acc: 81.68%, Test Loss: 1.3873, Test Acc: 80.70%, LR: 0.001000, Time: 69.15s
# Best model saved with accuracy: 80.70%
# Epoch 123/200, Train Loss: 1.7591, Train Acc: 81.35%, Test Loss: 1.3989, Test Acc: 80.53%, LR: 0.001000, Time: 69.03s
# Epoch 124/200, Train Loss: 1.7719, Train Acc: 81.34%, Test Loss: 1.4492, Test Acc: 79.81%, LR: 0.001000, Time: 69.02s
# Epoch 125/200, Train Loss: 1.7562, Train Acc: 81.83%, Test Loss: 1.4043, Test Acc: 80.56%, LR: 0.001000, Time: 69.04s
# Epoch 126/200, Train Loss: 1.7183, Train Acc: 82.97%, Test Loss: 1.4111, Test Acc: 80.17%, LR: 0.001000, Time: 68.99s
# Epoch 127/200, Train Loss: 1.7235, Train Acc: 83.03%, Test Loss: 1.4058, Test Acc: 80.53%, LR: 0.001000, Time: 68.95s
# Epoch 128/200, Train Loss: 1.7460, Train Acc: 81.68%, Test Loss: 1.3988, Test Acc: 80.65%, LR: 0.001000, Time: 68.91s
# Epoch 129/200, Train Loss: 1.7609, Train Acc: 81.66%, Test Loss: 1.3990, Test Acc: 80.35%, LR: 0.001000, Time: 68.91s
# Epoch 130/200, Train Loss: 1.7414, Train Acc: 82.49%, Test Loss: 1.3912, Test Acc: 80.61%, LR: 0.001000, Time: 68.99s
# Epoch 131/200, Train Loss: 1.7406, Train Acc: 81.18%, Test Loss: 1.4145, Test Acc: 80.30%, LR: 0.001000, Time: 69.07s
# Epoch 132/200, Train Loss: 1.7330, Train Acc: 82.40%, Test Loss: 1.4143, Test Acc: 80.07%, LR: 0.001000, Time: 69.00s
# Epoch 133/200, Train Loss: 1.7406, Train Acc: 81.86%, Test Loss: 1.4072, Test Acc: 80.10%, LR: 0.001000, Time: 69.03s
# Epoch 134/200, Train Loss: 1.7644, Train Acc: 81.60%, Test Loss: 1.4200, Test Acc: 80.08%, LR: 0.001000, Time: 69.08s
# Epoch 135/200, Train Loss: 1.7169, Train Acc: 82.68%, Test Loss: 1.4198, Test Acc: 80.00%, LR: 0.001000, Time: 69.11s
# Epoch 136/200, Train Loss: 1.6750, Train Acc: 83.35%, Test Loss: 1.4034, Test Acc: 80.55%, LR: 0.001000, Time: 69.00s
# Epoch 137/200, Train Loss: 1.7342, Train Acc: 82.19%, Test Loss: 1.4084, Test Acc: 80.63%, LR: 0.001000, Time: 69.02s
# Epoch 138/200, Train Loss: 1.6756, Train Acc: 82.89%, Test Loss: 1.4150, Test Acc: 80.40%, LR: 0.001000, Time: 69.03s
# Epoch 139/200, Train Loss: 1.6463, Train Acc: 84.58%, Test Loss: 1.4222, Test Acc: 80.50%, LR: 0.001000, Time: 69.08s
# Epoch 140/200, Train Loss: 1.7060, Train Acc: 82.61%, Test Loss: 1.3911, Test Acc: 80.90%, LR: 0.001000, Time: 69.07s
# Best model saved with accuracy: 80.90%
# Epoch 141/200, Train Loss: 1.7451, Train Acc: 82.21%, Test Loss: 1.3954, Test Acc: 80.84%, LR: 0.001000, Time: 68.97s
# Epoch 142/200, Train Loss: 1.7008, Train Acc: 83.74%, Test Loss: 1.4077, Test Acc: 80.52%, LR: 0.001000, Time: 69.15s
# Epoch 143/200, Train Loss: 1.6985, Train Acc: 83.27%, Test Loss: 1.4041, Test Acc: 80.30%, LR: 0.001000, Time: 69.05s
# Epoch 144/200, Train Loss: 1.6657, Train Acc: 83.54%, Test Loss: 1.4133, Test Acc: 80.14%, LR: 0.001000, Time: 68.96s
# Epoch 145/200, Train Loss: 1.7331, Train Acc: 82.39%, Test Loss: 1.4284, Test Acc: 80.16%, LR: 0.001000, Time: 68.93s
# Epoch 146/200, Train Loss: 1.6474, Train Acc: 84.14%, Test Loss: 1.4002, Test Acc: 80.29%, LR: 0.001000, Time: 68.97s
# Epoch 147/200, Train Loss: 1.6763, Train Acc: 83.57%, Test Loss: 1.4371, Test Acc: 80.02%, LR: 0.001000, Time: 69.03s
# Epoch 148/200, Train Loss: 1.6992, Train Acc: 83.62%, Test Loss: 1.4080, Test Acc: 80.41%, LR: 0.001000, Time: 68.95s
# Epoch 149/200, Train Loss: 1.6936, Train Acc: 83.05%, Test Loss: 1.4211, Test Acc: 80.16%, LR: 0.001000, Time: 68.98s
# Epoch 150/200, Train Loss: 1.6709, Train Acc: 83.73%, Test Loss: 1.4266, Test Acc: 80.37%, LR: 0.000100, Time: 69.04s
# Epoch 151/200, Train Loss: 1.6320, Train Acc: 85.11%, Test Loss: 1.4055, Test Acc: 80.98%, LR: 0.000100, Time: 69.09s
# Best model saved with accuracy: 80.98%
# Epoch 152/200, Train Loss: 1.6141, Train Acc: 84.98%, Test Loss: 1.3939, Test Acc: 81.28%, LR: 0.000100, Time: 69.03s
# Best model saved with accuracy: 81.28%
# Epoch 153/200, Train Loss: 1.6408, Train Acc: 84.66%, Test Loss: 1.4161, Test Acc: 80.67%, LR: 0.000100, Time: 69.06s
# Epoch 154/200, Train Loss: 1.6727, Train Acc: 84.88%, Test Loss: 1.4060, Test Acc: 80.90%, LR: 0.000100, Time: 69.14s
# Epoch 155/200, Train Loss: 1.6324, Train Acc: 84.79%, Test Loss: 1.3838, Test Acc: 81.29%, LR: 0.000100, Time: 69.11s
# Best model saved with accuracy: 81.29%
# Epoch 156/200, Train Loss: 1.6364, Train Acc: 84.83%, Test Loss: 1.3882, Test Acc: 81.29%, LR: 0.000100, Time: 69.15s
# Epoch 157/200, Train Loss: 1.6168, Train Acc: 86.21%, Test Loss: 1.4010, Test Acc: 81.11%, LR: 0.000100, Time: 69.11s
# Epoch 158/200, Train Loss: 1.6054, Train Acc: 85.44%, Test Loss: 1.3894, Test Acc: 81.25%, LR: 0.000100, Time: 69.00s
# Epoch 159/200, Train Loss: 1.6144, Train Acc: 85.28%, Test Loss: 1.3884, Test Acc: 80.93%, LR: 0.000100, Time: 69.09s
# Epoch 160/200, Train Loss: 1.6382, Train Acc: 85.30%, Test Loss: 1.3754, Test Acc: 81.17%, LR: 0.000100, Time: 68.99s
# Epoch 161/200, Train Loss: 1.6582, Train Acc: 84.28%, Test Loss: 1.3853, Test Acc: 81.06%, LR: 0.000100, Time: 68.95s
# Epoch 162/200, Train Loss: 1.6697, Train Acc: 84.03%, Test Loss: 1.3895, Test Acc: 81.14%, LR: 0.000100, Time: 69.10s
# Epoch 163/200, Train Loss: 1.6483, Train Acc: 84.85%, Test Loss: 1.4288, Test Acc: 80.72%, LR: 0.000100, Time: 69.07s
# Epoch 164/200, Train Loss: 1.6066, Train Acc: 85.86%, Test Loss: 1.3860, Test Acc: 81.26%, LR: 0.000100, Time: 68.98s
# Epoch 165/200, Train Loss: 1.6155, Train Acc: 85.06%, Test Loss: 1.4020, Test Acc: 80.90%, LR: 0.000100, Time: 69.02s
# Epoch 166/200, Train Loss: 1.5725, Train Acc: 86.38%, Test Loss: 1.3794, Test Acc: 81.32%, LR: 0.000100, Time: 68.96s
# Best model saved with accuracy: 81.32%
# Epoch 167/200, Train Loss: 1.6367, Train Acc: 85.18%, Test Loss: 1.3784, Test Acc: 81.52%, LR: 0.000100, Time: 69.04s
# Best model saved with accuracy: 81.52%
# Epoch 168/200, Train Loss: 1.5982, Train Acc: 85.98%, Test Loss: 1.4179, Test Acc: 80.85%, LR: 0.000100, Time: 69.03s
# Epoch 169/200, Train Loss: 1.6280, Train Acc: 84.64%, Test Loss: 1.3890, Test Acc: 81.38%, LR: 0.000100, Time: 69.10s
# Epoch 170/200, Train Loss: 1.6309, Train Acc: 85.25%, Test Loss: 1.4067, Test Acc: 81.08%, LR: 0.000100, Time: 69.09s
# Epoch 171/200, Train Loss: 1.5848, Train Acc: 86.54%, Test Loss: 1.3822, Test Acc: 81.22%, LR: 0.000100, Time: 69.09s
# Epoch 172/200, Train Loss: 1.6118, Train Acc: 85.07%, Test Loss: 1.3926, Test Acc: 81.31%, LR: 0.000100, Time: 69.07s
# Epoch 173/200, Train Loss: 1.6486, Train Acc: 85.19%, Test Loss: 1.4035, Test Acc: 81.11%, LR: 0.000100, Time: 68.98s
# Epoch 174/200, Train Loss: 1.6079, Train Acc: 85.80%, Test Loss: 1.3917, Test Acc: 81.35%, LR: 0.000100, Time: 69.11s
# Epoch 175/200, Train Loss: 1.5707, Train Acc: 86.41%, Test Loss: 1.3869, Test Acc: 81.22%, LR: 0.000100, Time: 69.05s
# Epoch 176/200, Train Loss: 1.6468, Train Acc: 84.87%, Test Loss: 1.3998, Test Acc: 81.30%, LR: 0.000100, Time: 69.01s
# Epoch 177/200, Train Loss: 1.6385, Train Acc: 85.38%, Test Loss: 1.4032, Test Acc: 80.98%, LR: 0.000100, Time: 68.96s
# Epoch 178/200, Train Loss: 1.6302, Train Acc: 85.08%, Test Loss: 1.3871, Test Acc: 81.31%, LR: 0.000100, Time: 69.12s
# Epoch 179/200, Train Loss: 1.6090, Train Acc: 86.11%, Test Loss: 1.3898, Test Acc: 81.36%, LR: 0.000100, Time: 69.08s
# Epoch 180/200, Train Loss: 1.6257, Train Acc: 84.83%, Test Loss: 1.4022, Test Acc: 81.10%, LR: 0.000100, Time: 69.16s
# Epoch 181/200, Train Loss: 1.6872, Train Acc: 84.41%, Test Loss: 1.3978, Test Acc: 81.12%, LR: 0.000100, Time: 69.00s
# Epoch 182/200, Train Loss: 1.6219, Train Acc: 84.76%, Test Loss: 1.3901, Test Acc: 81.48%, LR: 0.000100, Time: 68.94s
# Epoch 183/200, Train Loss: 1.5781, Train Acc: 86.70%, Test Loss: 1.3739, Test Acc: 81.34%, LR: 0.000100, Time: 68.97s
# Epoch 184/200, Train Loss: 1.5993, Train Acc: 86.00%, Test Loss: 1.4133, Test Acc: 81.01%, LR: 0.000100, Time: 68.95s
# Epoch 185/200, Train Loss: 1.6128, Train Acc: 85.63%, Test Loss: 1.3889, Test Acc: 81.14%, LR: 0.000100, Time: 68.95s
# Epoch 186/200, Train Loss: 1.6287, Train Acc: 85.31%, Test Loss: 1.3861, Test Acc: 81.21%, LR: 0.000100, Time: 69.02s
# Epoch 187/200, Train Loss: 1.5857, Train Acc: 86.12%, Test Loss: 1.3964, Test Acc: 81.02%, LR: 0.000100, Time: 68.97s
# Early stopping triggered at epoch 187
# Training completed in 215.76 minutes
# Best Test Accuracy: 81.52%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_size</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>best_acc</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>epoch_time</td><td>▃▃▃▃▃▃▃▃▃▃▂▂▃▂▃▂▂▂▂▂▂▁▅▄█▂▁▁▁▂▂▁▂▂▂▂▂▁▁▁</td></tr><tr><td>lr</td><td>██████████▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>total_time</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▃▃▃▄▄▄▄▄▄▄▆▆▆▆▆▆▆▆▇▇▇█████████████████</td></tr><tr><td>train_loss</td><td>█▇▆▅▅▅▅▅▅▅▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▄▄▄▄▄▄▄▄▅▅▄▇▇▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>val_loss</td><td>█▇▇▆▆▆▆▅▅▆▄▅▇▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_size</td><td>64</td></tr><tr><td>best_acc</td><td>81.52</td></tr><tr><td>epoch</td><td>187</td></tr><tr><td>epoch_time</td><td>68.97304</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>total_time</td><td>12945.87682</td></tr><tr><td>train_acc</td><td>86.116</td></tr><tr><td>train_loss</td><td>1.58572</td></tr><tr><td>val_acc</td><td>81.02</td></tr><tr><td>val_loss</td><td>1.39643</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sandy-sweep-1</strong> at: <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/dhzy6s4r' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline/runs/dhzy6s4r</a><br> View project at: <a href='https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline' target="_blank">https://wandb.ai/stefan-dorian-gavril-universitatea-alexandru-ioan-cuza-d/training_pipeline</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251121_235539-dhzy6s4r/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
